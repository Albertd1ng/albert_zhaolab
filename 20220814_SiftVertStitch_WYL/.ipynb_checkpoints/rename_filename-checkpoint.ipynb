# %%
import os
path=r"F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4"
file_list = os.listdir(path)
for i,files in enumerate(file_list):
    raw_dir = os.path.join(path,files)
    filename='z%.3d.tif'%(i)
    new_dir = os.path.join(path,filename)
    print(new_dir)
    os.rename(raw_dir,new_dir)
# Out:
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z000.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z001.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z002.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z003.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z004.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z005.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z006.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z007.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z008.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z009.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z010.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z011.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z012.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z013.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z014.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z015.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z016.tif
# F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\S4\z017.tif
# ...
