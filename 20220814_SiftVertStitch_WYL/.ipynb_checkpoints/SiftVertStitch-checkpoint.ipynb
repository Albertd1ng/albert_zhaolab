# %%
from lxml import etree
import numpy as np
import time
import cv2
import random
import sys
import os

def get_img_xml_info(xml_path):
    '''
    Read xml file and extract the information of dimensions and each tile
    return - (1)dim_elem_num - linspace(uint), the quantity of voxels for each dimension,
    (2)dim_len - linspace(float), the length for one 3D image,
    (3)voxel_len - lingspace(float), the length for a voxel,
    (4)tile_num - int, the quantity of tiles,
    (5)tile_field - array(uint), the identifier of each file
    (6)tile_pos - array(float), the XYZ position information of each tile
    '''
    parser=etree.XMLParser()
    my_et=etree.parse(xml_path,parser=parser)
    dim_attrib=my_et.xpath('//Dimensions/DimensionDescription')
    dim_elem_num=np.zeros(3,dtype='uint')
    dim_len=np.zeros(3)
    for i in range(3):
        dim_elem_num[i],dim_len[i]=dim_attrib[i].attrib['NumberOfElements'],dim_attrib[i].attrib['Length']
    voxel_len=dim_len/dim_elem_num
    return dim_elem_num,dim_len,voxel_len

def import_2D_img(img_path,img_name,z_th):
    one_img_name=r'%s\%sz%.3d.tif'%(img_path,img_name,z_th)
    return cv2.imread(one_img_name,cv2.IMREAD_GRAYSCALE)

def pyr_down_img(img,times=1):
    img_down=cv2.pyrDown(img)
    for i in range(times-1):
        img_down=cv2.pyrDown(img_down)
    return img_down

def loss_fun(ovl1,ovl2):
    ovl1,ovl2=ovl1.astype('float32'),ovl2.astype('float32')
    loss=np.sum((ovl1-ovl2)**2)/np.sqrt(np.sum(ovl1**2)*np.sum(ovl2**2))
    return loss

def calculate_xy_shift_by_RANSAC(img1,img2,pts1,pts2,loss_threshold=1,sample_time=1000):
    count=0
    matches_num=pts1.shape[0]
    RANSAC_num=np.int32(np.min((2,np.max((1,matches_num*0.1)))))
    loss_threshold=0.05
    loss_min=np.inf
    xy_shift_min=np.int32(np.zeros(2))
    if pts1.shape[0]==0 or pts1.shape[0]==0:
        return xy_shift_min,loss_min
    while(loss_min>loss_threshold and count<sample_time):
        count+=1
        index_list=random.sample(range(matches_num),RANSAC_num)
        xy_shift_all=pts2[index_list,:]-pts1[index_list,:]
        max_shift,min_shift=np.max(xy_shift_all,axis=0),np.min(xy_shift_all,axis=0)
        if any((max_shift-min_shift)>50):
            continue
        xy_shift=np.int32(np.round(np.mean(xy_shift_all,axis=0)))#XY
        if all(xy_shift==xy_shift_min):
            continue
        ovl1,ovl2=img1[np.max((0,-xy_shift[1])):,np.max((0,-xy_shift[0])):],img2[np.max((0,xy_shift[1])):,np.max((0,xy_shift[0])):]
        x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1])),np.min((ovl1.shape[0],ovl2.shape[0]))
        ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
        this_loss=loss_fun(ovl1,ovl2)
        #print(xy_shift,this_loss)
        if this_loss<loss_min:
            loss_min=this_loss
            xy_shift_min=xy_shift
    #print(xy_shift_min,loss_min)
    return xy_shift_min,loss_min

def calculate_xy_shift_by_BF(img1_down,img2_down,img1,img2,xy_shift):
    ################################################################
    xy_shift_min=np.zeros(0)
    loss_min=np.inf
    for x in range(-5,6):
        for y in range(-5,6):
            this_xy_shift=xy_shift+np.array([x,y],dtype='int32')
            #print(this_xy_shift)
            ovl1=img1_down[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2_down[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1])),np.min((ovl1.shape[0],ovl2.shape[0]))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
            #print(this_xy_shift,this_loss)
    print('first ',xy_shift_min,loss_min)
    ################################################################
    img1_down=pyr_down_img(img1,2)
    img2_down=pyr_down_img(img2,2)
    xy_shift_whole=xy_shift_min*2
    xy_shift_min=np.zeros(0)
    loss_min=np.inf
    for x in range(-18,19,3):
        for y in range(-18,19,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1_down[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2_down[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
#             if x==0 and y==0:
#                 cv2.imshow('1',ovl1)
#                 cv2.imshow('2',ovl2)
#                 cv2.waitKey()
#                 cv2.destroyAllWindows()
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    #print(xy_shift_min)
    xy_shift_whole=xy_shift_min
    for x in range(-2,3):
        for y in range(-2,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1_down[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2_down[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    print('second ',xy_shift_min,loss_min)
    ################################################################
    xy_shift_whole=xy_shift_min*4
    xy_shift_min=np.zeros(0)
    loss_min=np.inf
    for x in range(-18,19,3):
        for y in range(-18,19,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
#             if x==0 and y==0:
#                 cv2.imshow('1',ovl1)
#                 cv2.imshow('2',ovl2)
#                 cv2.waitKey()
#                 cv2.destroyAllWindows()
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    #print(xy_shift_min)
    xy_shift_whole=xy_shift_min
    for x in range(-2,3):
        for y in range(-2,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    print('third ',xy_shift_min,loss_min)
    return xy_shift_min,loss_min

def update_lower_layer_info(xy_shift,axis_range1,axis_range2):
    axis_range=np.zeros((2,2))
    axis_range[0,0]=axis_range1[0,0]-xy_shift[0]
    axis_range[0,1]=axis_range2[0,1]-axis_range2[0,0]+axis_range1[0,0]-xy_shift[0]
    axis_range[1,0]=axis_range1[1,0]-xy_shift[1]
    axis_range[1,1]=axis_range2[1,1]-axis_range2[1,0]+axis_range1[1,0]-xy_shift[1]
    return axis_range

def adjust_contrast(img1,img2):
    img1,img2=img1.astype('float32'),img2.astype('float32')
    m1,m2=np.mean(img1),np.mean(img2)
    m=np.max((m1,m2,40))
    #print(m,m1,m2)
    img1=np.uint8(np.clip(m/m1*img1,0,255))
    img2=np.uint8(np.clip(m/m2*img2,0,255))
    return img1,img2

def get_axis_range_from_img(img_path,img_name):
    img=import_2D_img(img_path,img_name,0)
    axis_range=np.zeros((2,2))
    axis_range[1,1],axis_range[0,1]=img.shape[0],img.shape[1]
    return axis_range

def start_vertical_stitch(i,img_path,save_path,file_name,img_name):
    sift=cv2.xfeatures2d.SIFT_create()
    bf=cv2.BFMatcher()
    img_path1,img_path2=img_path+'\\'+file_name%(i),img_path+'\\'+file_name%(i+1)
    dim_elem_num1,dim_elem_num2=len(os.listdir(img_path1)),len(os.listdir(img_path1))
    axis_range1,axis_range2=get_axis_range_from_img(img_path1,img_name),get_axis_range_from_img(img_path1,img_name)
    
    img1=cv2.medianBlur(import_2D_img(img_path1,img_name,dim_elem_num1-1),3)
    
    step=1
    loss_min=np.inf
    index_min=-1
    xy_shift_min=np.zeros(2)
    for j in range(10,np.uint32(np.round(dim_elem_num2*0.2)),step):
        img2=cv2.medianBlur(import_2D_img(img_path2,img_name,j),3)
        img1_down=pyr_down_img(img1,3)
        img2_down=pyr_down_img(img2,3)
        img1_down,img2_down=adjust_contrast(img1_down,img2_down)
        kpts1,des1=sift.detectAndCompute(img1_down,None)
        kpts2,des2=sift.detectAndCompute(img2_down,None)
        kp1,kp2=np.float32([kp.pt for kp in kpts1]),np.float32([kp.pt for kp in kpts2])
        matches=bf.knnMatch(des1,des2,k=2)
        good_matches=[]
        good=[]
        for m in matches:
            if len(m)==2 and m[0].distance<0.75*m[1].distance:
                good_matches.append((m[0].queryIdx,m[0].trainIdx))
                good.append(m[0])
        img3=cv2.drawMatches(img1_down,kpts1,img2_down,kpts2,good,None,flags=2)
        cv2.imshow('3',img3)
        cv2.waitKey(3000)
        cv2.destroyAllWindows()
        pts1,pts2=np.float32([kp1[i,:] for (i,_) in good_matches]),np.float32([kp2[j,:] for (_,j) in good_matches])
        xy_shift,this_loss=calculate_xy_shift_by_RANSAC(img1_down,img2_down,pts1,pts2)
        print('%d.th layer for pyrDown image, xy_shift is %s, loss is %.8f'%(j,str(xy_shift),this_loss))
        xy_shift,this_loss=calculate_xy_shift_by_BF(img1_down,img2_down,img1,img2,xy_shift)
        print('%d.th layer for whole image, xy_shift is %s, loss is %.8f'%(j,str(xy_shift),this_loss))
        if this_loss<loss_min:
            loss_min=this_loss
            xy_shift_min[0],xy_shift_min[1]=xy_shift[0],xy_shift[1]
            index_min=j
    print('################################################################################')
    print('Finally the matched one is %d.th layer, xy_shift is %s, loss is %.8f'%(index_min,str(xy_shift_min),loss_min))
    print('################################################################################')
    
    print('start saving data')
    axis_range2=update_lower_layer_info(xy_shift_min,axis_range1,axis_range2)
    np.save(save_path+r'\first_last_index_%d.npy'%(i+1),np.array([index_min,dim_elem_num],dtype='uint32'))
    np.save(save_path+r'\axis_range_%d.npy'%(i+1),axis_range2)
    print('end saving data')

# %%
if __name__=='__main__':
    img_path=r'F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN'
    file_name=r'S%d'
    img_name=r''
    save_path=r'C:\Users\dingj\ZhaoLab\20220814_SiftVertStitch_WYL'
    layer_num=4
    for i in range(1,layer_num+1):
        dim_elem_num=len(os.listdir(img_path+'\\'+file_name%(i)))
        np.save('first_last_index_%d.npy'%(i),np.array([0,dim_elem_num-1]))
        print(dim_elem_num)
        if i==1:
            img=import_2D_img(img_path+'\\'+file_name%(i),img_name,0)
            axis_range=np.zeros((2,2))
            axis_range[1,1],axis_range[0,1]=img.shape[0],img.shape[1]
            print(axis_range)
            np.save(save_path+r'\axis_range_%d.npy'%(i),axis_range)
    for i in range(1,layer_num):
        start_vertical_stitch(i,img_path,save_path,file_name,img_name)
# Out:
# 242
# [[   0. 4254.]
#  [   0. 4682.]]
# 242
# 242
# 241
# 10.th layer for pyrDown image, xy_shift is [-3  1], loss is 0.02286655
# first  [-4 -2] 0.021653203
# second  [-10   2] 0.12790072
# third  [-20   5] 0.13964298
# 10.th layer for whole image, xy_shift is [-20   5], loss is 0.13964298
# 11.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02215685
# first  [-4 -2] 0.021483641
# second  [-10   2] 0.1275784
# third  [-20   4] 0.13849227
# 11.th layer for whole image, xy_shift is [-20   4], loss is 0.13849227
# 12.th layer for pyrDown image, xy_shift is [-4  1], loss is 0.02219105
# first  [-4 -2] 0.021309536
# second  [-9  2] 0.1269234
# third  [-16   0] 0.1374781
# 12.th layer for whole image, xy_shift is [-16   0], loss is 0.13747810
# 13.th layer for pyrDown image, xy_shift is [-4  1], loss is 0.02210139
# first  [-4 -2] 0.02126807
# second  [-9  2] 0.1259591
# third  [-16   2] 0.13645096
# 13.th layer for whole image, xy_shift is [-16   2], loss is 0.13645096
# 14.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02206298
# first  [-4 -1] 0.021176437
# second  [-10   2] 0.12477199
# third  [-20   1] 0.13480344
# 14.th layer for whole image, xy_shift is [-20   1], loss is 0.13480344
# 15.th layer for pyrDown image, xy_shift is [-5 -8], loss is 0.02493074
# first  [-4 -3] 0.021494105
# second  [-10   2] 0.12409977
# third  [-20   1] 0.13395953
# 15.th layer for whole image, xy_shift is [-20   1], loss is 0.13395953
# 16.th layer for pyrDown image, xy_shift is [-1 -3], loss is 0.02243707
# first  [-4 -1] 0.020996712
# second  [-9  1] 0.12321461
# third  [-16   0] 0.13268156
# 16.th layer for whole image, xy_shift is [-16   0], loss is 0.13268156
# 17.th layer for pyrDown image, xy_shift is [-3 -3], loss is 0.02060129
# first  [-4 -1] 0.020234998
# second  [-9  1] 0.12247488
# third  [-16   4] 0.13266426
# 17.th layer for whole image, xy_shift is [-16   4], loss is 0.13266426
# 18.th layer for pyrDown image, xy_shift is [-2 -2], loss is 0.02072647
# first  [-4 -2] 0.020191824
# second  [-9  1] 0.12121511
# third  [-16   1] 0.13133934
# 18.th layer for whole image, xy_shift is [-16   1], loss is 0.13133934
# 19.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02081109
# first  [-4 -1] 0.020090988
# second  [-10   1] 0.12021759
# third  [-20   0] 0.12867302
# 19.th layer for whole image, xy_shift is [-20   0], loss is 0.12867302
# 20.th layer for pyrDown image, xy_shift is [-1 -2], loss is 0.02136537
# first  [-4 -1] 0.019969597
# second  [-10   1] 0.1187222
# third  [-20   0] 0.12587945
# 20.th layer for whole image, xy_shift is [-20   0], loss is 0.12587945
# 21.th layer for pyrDown image, xy_shift is [-2 -4], loss is 0.02103369
# first  [-4 -1] 0.019692305
# second  [-10   1] 0.117548294
# third  [-20   2] 0.123298086
# 21.th layer for whole image, xy_shift is [-20   2], loss is 0.12329809
# 22.th layer for pyrDown image, xy_shift is [-5 -4], loss is 0.02044709
# first  [-4 -1] 0.019676743
# second  [-10   0] 0.116666086
# third  [-20   0] 0.12120764
# 22.th layer for whole image, xy_shift is [-20   0], loss is 0.12120764
# 23.th layer for pyrDown image, xy_shift is [ -8 -11], loss is 0.02789936
# first  [-4 -6] 0.021668322
# second  [-10   0] 0.11557754
# third  [-20   0] 0.11965215
# 23.th layer for whole image, xy_shift is [-20   0], loss is 0.11965215
# 24.th layer for pyrDown image, xy_shift is [ -9 -10], loss is 0.02805964
# first  [-4 -5] 0.020871915
# second  [-5  0] 0.11492971
# third  [-2 -1] 0.11881597
# 24.th layer for whole image, xy_shift is [-2 -1], loss is 0.11881597
# 25.th layer for pyrDown image, xy_shift is [-1  0], loss is 0.02187670
# first  [-4 -1] 0.01983567
# second  [-6 -1] 0.11462656
# third  [-4  0] 0.11985398
# 25.th layer for whole image, xy_shift is [-4  0], loss is 0.11985398
# 26.th layer for pyrDown image, xy_shift is [ -8 -10], loss is 0.02779938
# first  [-4 -5] 0.021558056
# second  [-6 -1] 0.114287
# third  [-7 -6] 0.120203346
# 26.th layer for whole image, xy_shift is [-7 -6], loss is 0.12020335
# 27.th layer for pyrDown image, xy_shift is [ -6 -11], loss is 0.02835926
# first  [-4 -6] 0.022635994
# second  [-7 -1] 0.11428488
# third  [-8 -6] 0.12009825
# 27.th layer for whole image, xy_shift is [-8 -6], loss is 0.12009825
# 28.th layer for pyrDown image, xy_shift is [-1  0], loss is 0.02311579
# first  [-4 -1] 0.021037165
# second  [-7 -1] 0.11365598
# third  [-8 -6] 0.11853509
# 28.th layer for whole image, xy_shift is [-8 -6], loss is 0.11853509
# 29.th layer for pyrDown image, xy_shift is [-4 -1], loss is 0.02100263
# first  [-4 -1] 0.021002633
# second  [-7 -1] 0.11264613
# third  [-8 -6] 0.11576173
# 29.th layer for whole image, xy_shift is [-8 -6], loss is 0.11576173
# 30.th layer for pyrDown image, xy_shift is [-8 -9], loss is 0.02718763
# first  [-4 -4] 0.021346677
# second  [-8 -1] 0.1109075
# third  [-12  -6] 0.11361229
# 30.th layer for whole image, xy_shift is [-12  -6], loss is 0.11361229
# 31.th layer for pyrDown image, xy_shift is [-6 -7], loss is 0.02330622
# first  [-4 -2] 0.02025261
# second  [-8 -1] 0.10859762
# third  [-12  -6] 0.11098681
# 31.th layer for whole image, xy_shift is [-12  -6], loss is 0.11098681
# 32.th layer for pyrDown image, xy_shift is [-3 -2], loss is 0.01984990
# first  [-4 -2] 0.019722639
# second  [-7 -2] 0.105907634
# third  [-8 -6] 0.10846545
# 32.th layer for whole image, xy_shift is [-8 -6], loss is 0.10846545
# 33.th layer for pyrDown image, xy_shift is [-6 -4], loss is 0.02081073
# first  [-4 -2] 0.01941022
# second  [-7 -2] 0.10423888
# third  [-8 -8] 0.10654651
# 33.th layer for whole image, xy_shift is [-8 -8], loss is 0.10654651
# 34.th layer for pyrDown image, xy_shift is [-1 -2], loss is 0.02082036
# first  [-4 -2] 0.019197017
# second  [-7 -2] 0.102528945
# third  [-8 -8] 0.105087616
# 34.th layer for whole image, xy_shift is [-8 -8], loss is 0.10508762
# 35.th layer for pyrDown image, xy_shift is [-6 -2], loss is 0.02013702
# first  [-4 -2] 0.019108405
# second  [-7 -2] 0.1016867
# third  [-8 -8] 0.10385381
# 35.th layer for whole image, xy_shift is [-8 -8], loss is 0.10385381
# 36.th layer for pyrDown image, xy_shift is [-1 -2], loss is 0.02098844
# first  [-4 -2] 0.019186866
# second  [-7 -3] 0.10077595
# third  [-8 -8] 0.10330387
# 36.th layer for whole image, xy_shift is [-8 -8], loss is 0.10330387
# 37.th layer for pyrDown image, xy_shift is [-1 -4], loss is 0.02144464
# first  [-4 -2] 0.019141534
# second  [-7 -3] 0.09987459
# third  [-8 -8] 0.102911964
# 37.th layer for whole image, xy_shift is [-8 -8], loss is 0.10291196
# 38.th layer for pyrDown image, xy_shift is [-3 -2], loss is 0.01946064
# first  [-4 -2] 0.01922915
# second  [-7 -3] 0.09906978
# third  [ -8 -10] 0.103029445
# 38.th layer for whole image, xy_shift is [ -8 -10], loss is 0.10302944
# 39.th layer for pyrDown image, xy_shift is [ 0 -4], loss is 0.02292658
# first  [-4 -3] 0.019276833
# second  [-8 -3] 0.09848314
# third  [-12  -4] 0.10232746
# 39.th layer for whole image, xy_shift is [-12  -4], loss is 0.10232746
# 40.th layer for pyrDown image, xy_shift is [-4 -3], loss is 0.01938361
# first  [-4 -3] 0.019383615
# second  [-8 -4] 0.09808229
# third  [-13  -8] 0.10041096
# 40.th layer for whole image, xy_shift is [-13  -8], loss is 0.10041096
# 41.th layer for pyrDown image, xy_shift is [-6 -8], loss is 0.02414879
# first  [-4 -3] 0.019608807
# second  [-8 -4] 0.09804445
# third  [-12  -8] 0.09994852
# 41.th layer for whole image, xy_shift is [-12  -8], loss is 0.09994852
# 42.th layer for pyrDown image, xy_shift is [-6 -8], loss is 0.02441984
# first  [-4 -3] 0.019687193
# second  [-7 -7] 0.097816855
# third  [-8 -8] 0.100691564
# 42.th layer for whole image, xy_shift is [-8 -8], loss is 0.10069156
# 43.th layer for pyrDown image, xy_shift is [-3 -3], loss is 0.01986963
# first  [-4 -3] 0.019618284
# second  [-7 -7] 0.096873224
# third  [-8 -8] 0.10193731
# 43.th layer for whole image, xy_shift is [-8 -8], loss is 0.10193731
# 44.th layer for pyrDown image, xy_shift is [-6 -7], loss is 0.02234519
# first  [-4 -3] 0.018742727
# second  [-7 -7] 0.09571797
# third  [ -8 -12] 0.10253467
# 44.th layer for whole image, xy_shift is [ -8 -12], loss is 0.10253467
# 45.th layer for pyrDown image, xy_shift is [-4 -3], loss is 0.01841586
# first  [-4 -3] 0.01841586
# second  [-7 -7] 0.09404786
# third  [ -9 -14] 0.100356355
# 45.th layer for whole image, xy_shift is [ -9 -14], loss is 0.10035636
# 46.th layer for pyrDown image, xy_shift is [-1 -2], loss is 0.02086451
# first  [-4 -4] 0.017962012
# second  [-7 -7] 0.09241053
# third  [-20 -44] 0.09630771
# 46.th layer for whole image, xy_shift is [-20 -44], loss is 0.09630771
# 47.th layer for pyrDown image, xy_shift is [-3 -4], loss is 0.01790887
# first  [-4 -4] 0.017471464
# second  [-8 -4] 0.09097625
# third  [-12 -17] 0.09162921
# 47.th layer for whole image, xy_shift is [-12 -17], loss is 0.09162921
# ################################################################################
# Finally the matched one is 47.th layer, xy_shift is [-12. -17.], loss is 0.09162921
# ################################################################################
# start saving data
# end saving data
# 10.th layer for pyrDown image, xy_shift is [-2  3], loss is 0.04519908
# first  [-2  1] 0.04421405
# second  [-3  3] 0.10909582
# third  [-3 18] 0.12602542
# 10.th layer for whole image, xy_shift is [-3 18], loss is 0.12602542
# 11.th layer for pyrDown image, xy_shift is [-8  4], loss is 0.04885099
# first  [-3  0] 0.04317061
# second  [-3  3] 0.11050539
# third  [-2 19] 0.12628277
# 11.th layer for whole image, xy_shift is [-2 19], loss is 0.12628277
# 12.th layer for pyrDown image, xy_shift is [-2  2], loss is 0.04289485
# first  [-2  1] 0.04260326
# second  [-4  2] 0.1111262
# third  [-2 17] 0.12552883
# 12.th layer for whole image, xy_shift is [-2 17], loss is 0.12552883
# 13.th layer for pyrDown image, xy_shift is [-2  2], loss is 0.04238502
# first  [-3  0] 0.0420035
# second  [-4  2] 0.11048155
# third  [-2  8] 0.12423438
# 13.th layer for whole image, xy_shift is [-2  8], loss is 0.12423438
# 14.th layer for pyrDown image, xy_shift is [-3  5], loss is 0.04434093
# first  [-3  0] 0.041485947
# second  [-4  2] 0.10974625
# third  [-2 13] 0.12445734
# 14.th layer for whole image, xy_shift is [-2 13], loss is 0.12445734
# 15.th layer for pyrDown image, xy_shift is [-2  4], loss is 0.04365651
# first  [-3  0] 0.04153258
# second  [-4  2] 0.10951049
# third  [2 2] 0.12472138
# 15.th layer for whole image, xy_shift is [2 2], loss is 0.12472138
# 16.th layer for pyrDown image, xy_shift is [-5 -6], loss is 0.04472648
# first  [-3 -1] 0.041282978
# second  [-4  2] 0.10922729
# third  [2 2] 0.12405003
# 16.th layer for whole image, xy_shift is [2 2], loss is 0.12405003
# 17.th layer for pyrDown image, xy_shift is [ -7 -12], loss is 0.05253167
# first  [-2 -7] 0.044301804
# second  [-5  0] 0.10912223
# third  [0 6] 0.12312874
# 17.th layer for whole image, xy_shift is [0 6], loss is 0.12312874
# 18.th layer for pyrDown image, xy_shift is [-1  2], loss is 0.04228248
# first  [-3 -1] 0.04095879
# second  [-5  0] 0.10839716
# third  [0 8] 0.12058524
# 18.th layer for whole image, xy_shift is [0 8], loss is 0.12058524
# 19.th layer for pyrDown image, xy_shift is [0 1], loss is 0.04160231
# first  [-3 -2] 0.039937537
# second  [-5  0] 0.1074298
# third  [0 3] 0.117270574
# 19.th layer for whole image, xy_shift is [0 3], loss is 0.11727057
# 20.th layer for pyrDown image, xy_shift is [  0 -10], loss is 0.04661708
# first  [-3 -5] 0.04117121
# second  [-6 -5] 0.10562349
# third  [-4  0] 0.11373516
# 20.th layer for whole image, xy_shift is [-4  0], loss is 0.11373516
# 21.th layer for pyrDown image, xy_shift is [-6  1], loss is 0.04140753
# first  [-3 -2] 0.0384517
# second  [-6 -5] 0.10301662
# third  [-4  0] 0.1086406
# 21.th layer for whole image, xy_shift is [-4  0], loss is 0.10864060
# 22.th layer for pyrDown image, xy_shift is [-1 -8], loss is 0.04260744
# first  [-3 -3] 0.038068604
# second  [-6 -5] 0.10101683
# third  [-4  0] 0.10404291
# 22.th layer for whole image, xy_shift is [-4  0], loss is 0.10404291
# 23.th layer for pyrDown image, xy_shift is [ 4 -5], loss is 0.04514348
# first  [-1 -1] 0.03835999
# second  [-6 -5] 0.09951229
# third  [-4  0] 0.10166514
# 23.th layer for whole image, xy_shift is [-4  0], loss is 0.10166514
# 24.th layer for pyrDown image, xy_shift is [-4 -5], loss is 0.03927796
# first  [-3 -2] 0.037013054
# second  [-6 -5] 0.09781633
# third  [-4  0] 0.099845864
# 24.th layer for whole image, xy_shift is [-4  0], loss is 0.09984586
# 25.th layer for pyrDown image, xy_shift is [-5  3], loss is 0.04030231
# first  [-3 -2] 0.03648858
# second  [-7 -5] 0.09581009
# third  [-8  0] 0.09889402
# 25.th layer for whole image, xy_shift is [-8  0], loss is 0.09889402
# 26.th layer for pyrDown image, xy_shift is [-6 -3], loss is 0.03808027
# first  [-3 -2] 0.03603171
# second  [-6 -4] 0.09388372
# third  [-4  4] 0.09624557
# 26.th layer for whole image, xy_shift is [-4  4], loss is 0.09624557
# 27.th layer for pyrDown image, xy_shift is [-5  3], loss is 0.03937353
# first  [-3 -2] 0.035710048
# second  [-6 -3] 0.09278879
# third  [-4  6] 0.094296314
# 27.th layer for whole image, xy_shift is [-4  6], loss is 0.09429631
# 28.th layer for pyrDown image, xy_shift is [-6  4], loss is 0.04169013
# first  [-3 -1] 0.03608239
# second  [-7 -2] 0.09170888
# third  [-8  0] 0.092545114
# 28.th layer for whole image, xy_shift is [-8  0], loss is 0.09254511
# 29.th layer for pyrDown image, xy_shift is [ -7 -11], loss is 0.04827011
# first  [-2 -6] 0.038227867
# second  [-6 -2] 0.09055121
# third  [-4  6] 0.09026137
# 29.th layer for whole image, xy_shift is [-4  6], loss is 0.09026137
# 30.th layer for pyrDown image, xy_shift is [ -3 -10], loss is 0.04325926
# first  [-2 -5] 0.037436537
# second  [-1  1] 0.09006354
# third  [2 6] 0.087311074
# 30.th layer for whole image, xy_shift is [2 6], loss is 0.08731107
# 31.th layer for pyrDown image, xy_shift is [ -7 -11], loss is 0.04794160
# first  [-3 -6] 0.037697624
# second  [-2  1] 0.08924959
# third  [2 6] 0.08604369
# 31.th layer for whole image, xy_shift is [2 6], loss is 0.08604369
# 32.th layer for pyrDown image, xy_shift is [-5 -3], loss is 0.03748811
# first  [-2 -1] 0.035370797
# second  [-3  1] 0.088121586
# third  [2 0] 0.08457096
# 32.th layer for whole image, xy_shift is [2 0], loss is 0.08457096
# 33.th layer for pyrDown image, xy_shift is [-1  2], loss is 0.03627881
# first  [-2 -1] 0.035067026
# second  [-3  1] 0.08717478
# third  [2 5] 0.08321814
# 33.th layer for whole image, xy_shift is [2 5], loss is 0.08321814
# 34.th layer for pyrDown image, xy_shift is [-1  1], loss is 0.03518633
# first  [-2 -2] 0.034736574
# second  [-3  1] 0.08613003
# third  [2 0] 0.08227522
# 34.th layer for whole image, xy_shift is [2 0], loss is 0.08227522
# 35.th layer for pyrDown image, xy_shift is [-5 -8], loss is 0.04034504
# first  [-2 -3] 0.034449313
# second  [-3  1] 0.0849378
# third  [2 2] 0.08088302
# 35.th layer for whole image, xy_shift is [2 2], loss is 0.08088302
# 36.th layer for pyrDown image, xy_shift is [-4 -2], loss is 0.03490359
# first  [-2 -2] 0.033648442
# second  [-3  1] 0.08315069
# third  [2 6] 0.07897432
# 36.th layer for whole image, xy_shift is [2 6], loss is 0.07897432
# 37.th layer for pyrDown image, xy_shift is [-3 -8], loss is 0.03793069
# first  [-2 -3] 0.033255376
# second  [-3  1] 0.08177789
# third  [2 2] 0.07735219
# 37.th layer for whole image, xy_shift is [2 2], loss is 0.07735219
# 38.th layer for pyrDown image, xy_shift is [-1  1], loss is 0.03438424
# first  [-2 -3] 0.03326142
# second  [-4 -5] 0.080454625
# third  [2 0] 0.07548708
# 38.th layer for whole image, xy_shift is [2 0], loss is 0.07548708
# 39.th layer for pyrDown image, xy_shift is [-4 -8], loss is 0.03854202
# first  [-2 -3] 0.03296561
# second  [-4 -5] 0.079159215
# third  [2 0] 0.07436672
# 39.th layer for whole image, xy_shift is [2 0], loss is 0.07436672
# 40.th layer for pyrDown image, xy_shift is [-5 -9], loss is 0.04104544
# first  [-2 -4] 0.0331794
# second  [-4 -5] 0.07782359
# third  [2 0] 0.07331732
# 40.th layer for whole image, xy_shift is [2 0], loss is 0.07331732
# 41.th layer for pyrDown image, xy_shift is [ 1 -1], loss is 0.03365083
# first  [-2 -3] 0.031676047
# second  [-4 -6] 0.07634194
# third  [ 2 -4] 0.07293118
# 41.th layer for whole image, xy_shift is [ 2 -4], loss is 0.07293118
# 42.th layer for pyrDown image, xy_shift is [-1  0], loss is 0.03182378
# first  [-2 -3] 0.030993573
# second  [-4 -6] 0.07444962
# third  [ 2 -4] 0.0725558
# 42.th layer for whole image, xy_shift is [ 2 -4], loss is 0.07255580
# 43.th layer for pyrDown image, xy_shift is [-4 -8], loss is 0.03603557
# first  [-1 -3] 0.030486476
# second  [-4 -5] 0.07332139
# third  [2 0] 0.07146987
# 43.th layer for whole image, xy_shift is [2 0], loss is 0.07146987
# 44.th layer for pyrDown image, xy_shift is [-4 -7], loss is 0.03503099
# first  [-1 -3] 0.030371988
# second  [-3 -2] 0.072670445
# third  [ 2 10] 0.07128453
# 44.th layer for whole image, xy_shift is [ 2 10], loss is 0.07128453
# 45.th layer for pyrDown image, xy_shift is [-2 -6], loss is 0.03162164
# first  [-1 -2] 0.030312143
# second  [-3 -2] 0.072264366
# third  [2 1] 0.070448704
# 45.th layer for whole image, xy_shift is [2 1], loss is 0.07044870
# 46.th layer for pyrDown image, xy_shift is [-3 -2], loss is 0.03207040
# first  [-1 -3] 0.030535484
# second  [-3 -2] 0.07235057
# third  [2 0] 0.069478005
# 46.th layer for whole image, xy_shift is [2 0], loss is 0.06947801
# 47.th layer for pyrDown image, xy_shift is [-2 -6], loss is 0.03202441
# first  [-1 -2] 0.030514827
# second  [ 0 -4] 0.07220561
# third  [2 0] 0.06888654
# 47.th layer for whole image, xy_shift is [2 0], loss is 0.06888654
# ################################################################################
# Finally the matched one is 47.th layer, xy_shift is [2. 0.], loss is 0.06888654
# ################################################################################
# start saving data
# end saving data
# 10.th layer for pyrDown image, xy_shift is [ 0 -4], loss is 0.03762732
# first  [-1 -1] 0.036334734
# second  [-2  7] 0.11334183
# third  [-2 45] 0.11614889
# 10.th layer for whole image, xy_shift is [-2 45], loss is 0.11614889
# 11.th layer for pyrDown image, xy_shift is [-2  0], loss is 0.03672349
# first  [-1 -1] 0.036168206
# second  [-2  7] 0.112378314
# third  [-2 45] 0.115128584
# 11.th layer for whole image, xy_shift is [-2 45], loss is 0.11512858
# 12.th layer for pyrDown image, xy_shift is [-1  1], loss is 0.03604464
# first  [-1 -1] 0.03573631
# second  [-2  7] 0.11089128
# third  [-2 43] 0.11369506
# 12.th layer for whole image, xy_shift is [-2 43], loss is 0.11369506
# 13.th layer for pyrDown image, xy_shift is [0 5], loss is 0.03790991
# first  [-1  0] 0.035307936
# second  [-2  7] 0.10913433
# third  [-2 47] 0.11214538
# 13.th layer for whole image, xy_shift is [-2 47], loss is 0.11214538
# 14.th layer for pyrDown image, xy_shift is [0 1], loss is 0.03516845
# first  [-1 -1] 0.034796823
# second  [-2  7] 0.10732079
# third  [-2 47] 0.11046327
# 14.th layer for whole image, xy_shift is [-2 47], loss is 0.11046327
# 15.th layer for pyrDown image, xy_shift is [  4 -14], loss is 0.04943150
# first  [-1 -9] 0.039982527
# second  [-1  0] 0.10622142
# third  [-2 20] 0.10996173
# 15.th layer for whole image, xy_shift is [-2 20], loss is 0.10996173
# 16.th layer for pyrDown image, xy_shift is [0 1], loss is 0.03417761
# first  [-1 -1] 0.0338073
# second  [-2  7] 0.10359089
# third  [-2 45] 0.10734127
# 16.th layer for whole image, xy_shift is [-2 45], loss is 0.10734127
# 17.th layer for pyrDown image, xy_shift is [-8  9], loss is 0.04817675
# first  [-3  4] 0.03662639
# second  [-2  7] 0.102572344
# third  [-2 45] 0.10621951
# 17.th layer for whole image, xy_shift is [-2 45], loss is 0.10621951
# 18.th layer for pyrDown image, xy_shift is [1 5], loss is 0.03774378
# first  [0 0] 0.033523418
# second  [-1  0] 0.10213071
# third  [-2 20] 0.105617195
# 18.th layer for whole image, xy_shift is [-2 20], loss is 0.10561720
# 19.th layer for pyrDown image, xy_shift is [1 1], loss is 0.03448137
# first  [0 0] 0.03332022
# second  [-1  0] 0.10121287
# third  [-2 20] 0.10369628
# 19.th layer for whole image, xy_shift is [-2 20], loss is 0.10369628
# 20.th layer for pyrDown image, xy_shift is [1 1], loss is 0.03421733
# first  [0 0] 0.03302477
# second  [-1  1] 0.10005056
# third  [-2 24] 0.10188343
# 20.th layer for whole image, xy_shift is [-2 24], loss is 0.10188343
# 21.th layer for pyrDown image, xy_shift is [1 4], loss is 0.03475727
# first  [0 0] 0.031579368
# second  [-1  1] 0.09860538
# third  [-2 24] 0.0997347
# 21.th layer for whole image, xy_shift is [-2 24], loss is 0.09973470
# 22.th layer for pyrDown image, xy_shift is [0 1], loss is 0.03137776
# first  [0 0] 0.031087622
# second  [-1  1] 0.097190045
# third  [-2 24] 0.097788945
# 22.th layer for whole image, xy_shift is [-2 24], loss is 0.09778894
# 23.th layer for pyrDown image, xy_shift is [0 5], loss is 0.03417460
# first  [0 0] 0.030686898
# second  [0 1] 0.095947646
# third  [-2 24] 0.09561795
# 23.th layer for whole image, xy_shift is [-2 24], loss is 0.09561795
# 24.th layer for pyrDown image, xy_shift is [-1  1], loss is 0.03092631
# first  [0 0] 0.030449726
# second  [0 1] 0.09506707
# third  [-2 24] 0.09332252
# 24.th layer for whole image, xy_shift is [-2 24], loss is 0.09332252
# 25.th layer for pyrDown image, xy_shift is [-1  1], loss is 0.03083569
# first  [0 0] 0.030377869
# second  [0 1] 0.09407285
# third  [-2 24] 0.09159269
# 25.th layer for whole image, xy_shift is [-2 24], loss is 0.09159269
# 26.th layer for pyrDown image, xy_shift is [1 4], loss is 0.03314549
# first  [0 0] 0.03017243
# second  [-1  7] 0.09299921
# third  [-2 33] 0.089919925
# 26.th layer for whole image, xy_shift is [-2 33], loss is 0.08991992
# 27.th layer for pyrDown image, xy_shift is [-2  0], loss is 0.03116952
# first  [0 0] 0.029888123
# second  [-1  7] 0.09175908
# third  [-2 33] 0.08851014
# 27.th layer for whole image, xy_shift is [-2 33], loss is 0.08851014
# 28.th layer for pyrDown image, xy_shift is [-3  0], loss is 0.03165415
# first  [0 0] 0.029239828
# second  [-1  1] 0.09014988
# third  [-2 24] 0.08692713
# 28.th layer for whole image, xy_shift is [-2 24], loss is 0.08692713
# 29.th layer for pyrDown image, xy_shift is [-3 -1], loss is 0.03138889
# first  [0 0] 0.02877596
# second  [-1  1] 0.088459566
# third  [-2 24] 0.08536785
# 29.th layer for whole image, xy_shift is [-2 24], loss is 0.08536785
# 30.th layer for pyrDown image, xy_shift is [-3 -1], loss is 0.03126447
# first  [0 0] 0.028480519
# second  [-1  2] 0.086980306
# third  [-2 25] 0.083667085
# 30.th layer for whole image, xy_shift is [-2 25], loss is 0.08366708
# 31.th layer for pyrDown image, xy_shift is [-3 -1], loss is 0.03141734
# first  [0 0] 0.02845018
# second  [-1  2] 0.08582009
# third  [-2 25] 0.082505934
# 31.th layer for whole image, xy_shift is [-2 25], loss is 0.08250593
# 32.th layer for pyrDown image, xy_shift is [0 4], loss is 0.03106753
# first  [0 1] 0.028188748
# second  [0 2] 0.08430766
# third  [-2 25] 0.080936566
# 32.th layer for whole image, xy_shift is [-2 25], loss is 0.08093657
# 33.th layer for pyrDown image, xy_shift is [-3 -1], loss is 0.03148280
# first  [0 1] 0.027781319
# second  [0 2] 0.08312608
# third  [-2 25] 0.07949951
# 33.th layer for whole image, xy_shift is [-2 25], loss is 0.07949951
# 34.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02990496
# first  [0 1] 0.027336128
# second  [0 2] 0.08204979
# third  [-2 23] 0.07791342
# 34.th layer for whole image, xy_shift is [-2 23], loss is 0.07791342
# 35.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02973050
# first  [0 1] 0.02674174
# second  [0 3] 0.08102438
# third  [-2 23] 0.07649549
# 35.th layer for whole image, xy_shift is [-2 23], loss is 0.07649549
# 36.th layer for pyrDown image, xy_shift is [-2 -1], loss is 0.02976117
# first  [0 1] 0.02631091
# second  [0 3] 0.08014398
# third  [-2 21] 0.07470951
# 36.th layer for whole image, xy_shift is [-2 21], loss is 0.07470951
# 37.th layer for pyrDown image, xy_shift is [1 3], loss is 0.02931182
# first  [0 1] 0.025885075
# second  [0 3] 0.07921467
# third  [-2 20] 0.07303361
# 37.th layer for whole image, xy_shift is [-2 20], loss is 0.07303361
# 38.th layer for pyrDown image, xy_shift is [-1  4], loss is 0.03064381
# first  [0 1] 0.025206447
# second  [0 3] 0.07817442
# third  [-2 19] 0.07172275
# 38.th layer for whole image, xy_shift is [-2 19], loss is 0.07172275
# 39.th layer for pyrDown image, xy_shift is [1 2], loss is 0.02681596
# first  [0 1] 0.024370419
# second  [0 3] 0.07623802
# third  [-2 19] 0.07047131
# 39.th layer for whole image, xy_shift is [-2 19], loss is 0.07047131
# 40.th layer for pyrDown image, xy_shift is [1 3], loss is 0.02860195
# first  [0 1] 0.023445033
# second  [0 2] 0.07400583
# third  [-2 17] 0.06885036
# 40.th layer for whole image, xy_shift is [-2 17], loss is 0.06885036
# 41.th layer for pyrDown image, xy_shift is [-1  5], loss is 0.03306569
# first  [0 1] 0.022474082
# second  [0 2] 0.07117687
# third  [-2 16] 0.06732302
# 41.th layer for whole image, xy_shift is [-2 16], loss is 0.06732302
# 42.th layer for pyrDown image, xy_shift is [-1  6], loss is 0.03487187
# first  [0 1] 0.020815268
# second  [0 2] 0.067392774
# third  [-2 15] 0.065914705
# 42.th layer for whole image, xy_shift is [-2 15], loss is 0.06591471
# 43.th layer for pyrDown image, xy_shift is [0 2], loss is 0.02062894
# first  [0 1] 0.018639004
# second  [0 2] 0.062137812
# third  [-2 15] 0.06453622
# 43.th layer for whole image, xy_shift is [-2 15], loss is 0.06453622
# 44.th layer for pyrDown image, xy_shift is [ 4 -2], loss is 0.03288465
# first  [0 1] 0.016205942
# second  [0 2] 0.056846518
# third  [-2 15] 0.06343351
# 44.th layer for whole image, xy_shift is [-2 15], loss is 0.06343351
# 45.th layer for pyrDown image, xy_shift is [0 2], loss is 0.01704556
# first  [0 1] 0.014066865
# second  [0 2] 0.051635925
# third  [-2 14] 0.062462196
# 45.th layer for whole image, xy_shift is [-2 14], loss is 0.06246220
# 46.th layer for pyrDown image, xy_shift is [0 2], loss is 0.01595158
# first  [0 1] 0.012539756
# second  [0 2] 0.04743348
# third  [ 5 13] 0.060842287
# 46.th layer for whole image, xy_shift is [ 5 13], loss is 0.06084229
# 47.th layer for pyrDown image, xy_shift is [0 1], loss is 0.01158753
# first  [0 1] 0.011587532
# second  [0 2] 0.04581683
# third  [-2 13] 0.060289733
# 47.th layer for whole image, xy_shift is [-2 13], loss is 0.06028973
# ################################################################################
# Finally the matched one is 47.th layer, xy_shift is [-2. 13.], loss is 0.06028973
# ################################################################################
# start saving data
# end saving data

# %%
img_path=r'F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN'
file_name=r'S%d'
img_name=r''
img_save_path=r'F:\20220811_VIP_Cre_DIOmS_RetromS_in_SCN\zstitched'
save_img_name=r'merged_stitched%.4d'
save_path=r'C:\Users\dingj\ZhaoLab\20220814_SiftVertStitch_WYL'
stitch_layer_num=4

axis_range_array=np.zeros((stitch_layer_num,4))
for i in range(1,stitch_layer_num+1):
    axis_range_array[i-1,:]=np.load(save_path+r'\axis_range_%d.npy'%(i)).reshape((1,-1))
xy_axis_range=np.zeros((2,2))
xy_axis_range[0,0],xy_axis_range[0,1]=np.min(axis_range_array[:,0])-2,np.max(axis_range_array[:,1])+100
xy_axis_range[1,0],xy_axis_range[1,1]=np.min(axis_range_array[:,2])-2,np.max(axis_range_array[:,3])+100
xy_voxel_num=np.int64(np.round((xy_axis_range[:,1]-xy_axis_range[:,0])+1))
print(xy_voxel_num)

img_num=0
for i in range(stitch_layer_num):
    first_last_index=np.load(save_path+r'\first_last_index_%d.npy'%(i+1))
    axis_range=np.load(save_path+r'\axis_range_%d.npy'%(i+1))
    this_img_path=img_path+'\\'+file_name%(i+1)
    x_th=np.int64(np.round((axis_range[0,0]-xy_axis_range[0,0])))
    y_th=np.int64(np.round((axis_range[1,0]-xy_axis_range[1,0])))
    for j in range(first_last_index[0],first_last_index[1]):
        this_img=np.zeros((xy_voxel_num[1::-1]),dtype='uint8')
        img_2D=import_2D_img(this_img_path,img_name,j)
        this_img[y_th:y_th+img_2D.shape[0],x_th:x_th+img_2D.shape[1]]=img_2D
        cv2.imwrite(r'%s\z%.4d.tif'%(img_save_path,img_num),this_img)
        img_num+=1
# Out:
# [4371 4815]
