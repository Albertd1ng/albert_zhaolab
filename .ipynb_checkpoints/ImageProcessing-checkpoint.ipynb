# %%
from lxml import etree
import numpy as np
import time
import cv2
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from multiprocessing import Manager,Value,Array,Process
import ctypes
import torch

#Functions
def import_img(img_path,ordinal,dim_elem_num):
    '''
    this function reads voxel information and return a 3D np_array.
    return - array, store the 3D image
    img_path - str, the file position,
    ordinal - int, the ordinal number for image,
    dim_elem_num - list, the quantities of voxels for each dimension.
    '''
    #s_time = time.time()
    voxel_array=np.zeros(tuple(dim_elem_num),dtype='uint8')#the array for storing image, dtyte should be changed according to image type
    #next statements get the img information according to image names, need to be changed according to different naming methods
    for i in range(dim_elem_num[2]):
        img_name=r'%s\Region 1_s%.4d_z%.3d_RAW_ch00.tif'%(img_path,ordinal,i)
        voxel_array[:,:,i]=cv2.imread(img_name)[:,:,0]
    #e_time = time.time()
    #print('import_img costs time - %f'%(e_time-s_time))
    return voxel_array

def get_2img_border(dim_elem_num,dim_len,voxel_len,tile_pos):
    '''
    get the border voxel index for two overlapping images
    return - array, the x/y/z_min/max voxel ordinal for each image,
    dim_elem_num - list, the quantities of voxels for each dimension,
    dim_len - list, the image length,
    tile_pos - array, xyz positions of each img.
    '''
    #s_time = time.time()
    #x/y/z_min/max, the positions of overlapping image border
    x_min,x_max=np.max(tile_pos[:,0]),np.min(tile_pos[:,0])+dim_len[0]
    y_min,y_max=np.max(tile_pos[:,1]),np.min(tile_pos[:,1])+dim_len[1]
    z_min,z_max=np.max(tile_pos[:,2]),np.min(tile_pos[:,2])+dim_len[2]
    #x/y/zv_min/max, the voxel index of overlapping image border
    xv1_min,xv1_max=np.round((x_min-tile_pos[0,0])/voxel_len[0]),np.round((x_max-tile_pos[0,0])/voxel_len[0])
    yv1_min,yv1_max=np.round((y_min-tile_pos[0,1])/voxel_len[1]),np.round((y_max-tile_pos[0,1])/voxel_len[1])
    zv1_min,zv1_max=np.round((z_min-tile_pos[0,2])/voxel_len[2]),np.round((z_max-tile_pos[0,2])/voxel_len[2])
    xv2_min,xv2_max=np.round((x_min-tile_pos[1,0])/voxel_len[0]),np.round((x_max-tile_pos[1,0])/voxel_len[0])
    yv2_min,yv2_max=np.round((y_min-tile_pos[1,1])/voxel_len[1]),np.round((y_max-tile_pos[1,1])/voxel_len[1])
    zv2_min,zv2_max=np.round((z_min-tile_pos[1,2])/voxel_len[2]),np.round((z_max-tile_pos[1,2])/voxel_len[2])
    voxel_border=np.array([[xv1_min,xv1_max,yv1_min,yv1_max,zv1_min,zv1_max],
              [xv2_min,xv2_max,yv2_min,yv2_max,zv2_min,zv2_max]],dtype='uint')
    #print(voxel_border)
    #assert xv1_min-xv1_max==xv2_min-xv2_max and yv1_min-yv1_max==yv2_min-yv2_max and zv1_min-zv1_max==zv2_min-zv2_max
    #e_time = time.time()
    #print('get_2img_border costs time - %f'%(e_time-s_time))
    return voxel_border

def loss_fun(ovl1,ovl2,xyz_shift,alpha):
    '''
    this fucntion calculate the loss function of two overlapping images
    return - float, loss fun of overlapping area
    xyz_shift - list, record the xyz shift of original position,
    alpha - a hyperparameter
    '''
    #s_time = time.time()
    if 0 in ovl1.shape or 0 in ovl2.shape:
        print('no overlapping area')
        return np.inf
    ovl1,ovl2=ovl1.astype('float64'),ovl2.astype('float64')
    a=np.sum((ovl1-ovl2)**2)/np.sqrt(np.sum(ovl1**2)*np.sum(ovl1**2))+alpha*np.sum(np.array(xyz_shift,dtype='float64')**2)
    print(ovl1.shape,a)
    #e_time = time.time()
    #print('loss_fun time - %f'%(e_time-s_time))
    return a
"""
def loss_fun(ovl1,ovl2,xyz_shift,alpha):
    '''
    this fucntion calculate the loss function of two overlapping images
    return - float, loss fun of overlapping area
    xyz_shift - list, record the xyz shift of original position,
    alpha - a hyperparameter
    '''
    #s_time = time.time()
    if 0 in ovl1.shape or 0 in ovl2.shape:
        print('no overlapping area')
        return np.inf
    ovl1,ovl2=ovl1.double(),ovl2.double()
    a=torch.sum((ovl1-ovl2)**2)/(torch.sqrt(torch.sum(ovl1**2))*torch.sqrt(torch.sum(ovl2**2)))+alpha*torch.sum(torch.tensor(xyz_shift,dtype=torch.double,device='cuda')**2)
    print(ovl1.shape,a)
    #e_time = time.time()
    #print('loss_fun time - %f'%(e_time-s_time))
    return a
"""
def get_2img_border_after_shift(dim_elem_num,voxel_border,xyz_shift):
    '''
    this function calculates the border of two partly overlapping images after translation
    return - array, the voxel index of overlapping area for each image
    dim_elem_num - the voxel quantities for each dimension
    voxel_border - array, the voxel index before translation
    xyz_shift - list, the translation for each dimension
    '''
    #s_time = time.time()
    border_after_shift=np.zeros((2,6),dtype='uint')
    #calcualte the border after translation for three dimensions
    for i in range(3):
        if voxel_border[0,2*i]<voxel_border[1,2*i]:
            border_after_shift[0,2*i],border_after_shift[0,2*i+1]=0,np.max([0,voxel_border[0,2*i+1]+xyz_shift[i]])
            border_after_shift[1,2*i],border_after_shift[1,2*i+1]=np.min([dim_elem_num[i],voxel_border[1,2*i]-xyz_shift[i]]),dim_elem_num[i]
        elif voxel_border[0,2*i]>voxel_border[1,2*i]:
            border_after_shift[0,2*i],border_after_shift[0,2*i+1]=np.min([dim_elem_num[i],voxel_border[0,2*i]+xyz_shift[i]]),dim_elem_num[i]
            border_after_shift[1,2*i],border_after_shift[1,2*i+1]=0,np.max([0,voxel_border[1,2*i+1]-xyz_shift[i]])
        else:
            #in this case, x_min=0, x_max=dim_elem_num[i]
            if xyz_shift[i]<0:
                border_after_shift[0,2*i],border_after_shift[0,2*i+1]=0,voxel_border[0,2*i+1]+xyz_shift[i]
                border_after_shift[1,2*i],border_after_shift[1,2*i+1]=-xyz_shift[i],voxel_border[1,2*i+1]
            else:
                border_after_shift[0,2*i],border_after_shift[0,2*i+1]=xyz_shift[i],voxel_border[0,2*i+1]
                border_after_shift[1,2*i],border_after_shift[1,2*i+1]=0,voxel_border[1,2*i+1]-xyz_shift[i]
    #assert border_after_shift[0,1]-border_after_shift[0,0]==border_after_shift[1,1]-border_after_shift[1,0]
    #assert border_after_shift[0,3]-border_after_shift[0,2]==border_after_shift[1,3]-border_after_shift[1,2]
    #assert border_after_shift[0,5]-border_after_shift[0,4]==border_after_shift[1,5]-border_after_shift[1,4]
    #e_time = time.time()
    #print('get_2img_border_after_shift - %f'%(e_time-s_time))
    return border_after_shift

def calculate_img_xyz_shift(img1,img2,dim_elem_num,voxel_border,voxel_range,step):
    '''
    #this function gets the best overlapping position for two partly overlapping images
    #return - list, the voxel translation quantities of img1 to be stitched to img2
    #voxel_border - array, voxel range for overlapping area,
    #voxel_range - list, the range need to be calculated,
    #step - int 
    '''
    #img1,img2=torch.from_numpy(img1),torch.from_numpy(img2)
    #img1.to(device='cuda')
    #img2.to(device='cuda')
    xv_shift,yv_shift,zv_shift=0,0,0
    loss_min=np.inf
    alpha=10e-6
    for x in range(-voxel_range[0],voxel_range[0]+1,step):
        for y in range(-voxel_range[1],voxel_range[1]+1,step):
            for z in range(-voxel_range[2],voxel_range[2]+1,step):
                border=get_2img_border_after_shift(dim_elem_num,voxel_border,[x,y,z])
                print(x,y,z)
                this_loss=loss_fun(img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]],
                                   img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[1,4]:border[1,5]],[x,y,z],alpha)
                if this_loss<loss_min:
                    loss_min=this_loss
                    xv_shift,yv_shift,zv_shift=x,y,z
    print(xv_shift,yv_shift,zv_shift,step)
    for x in range(xv_shift-2*step+1,xv_shift+2*step):
        for y in range(yv_shift-2*step+1,yv_shift+2*step):
            for z in range(zv_shift-2*step+1,zv_shift+2*step):
                border=get_2img_border_after_shift(dim_elem_num,voxel_border,[x,y,z])
                print(x,y,z)
                this_loss=loss_fun(img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]],
                                   img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[1,4]:border[1,5]],[x,y,z],alpha)
                if this_loss<loss_min:
                    loss_min=this_loss
                    xv_shift,yv_shift,zv_shift=x,y,z
    print(xv_shift,yv_shift,zv_shift,loss_min)
    return xv_shift,yv_shift,zv_shift
"""
def run_multiprocess(lock,if_tile_stitched,if_tile_being_process,img_path,dim_elem_num,dim_len,voxel_len,tile_pos,voxel_range,step):
    print(multiprocess.current_process().name)
    lock.acquire()
    usable_index=[index for index,i in enumerate(if_tile_stitched or if_tile_being_process) if i==False]
    i=usable_index[0]
    if_tile_being_process[i]=True
    lock.release()
    contact_index=np.argwhere(tile_contact[i,:])
    max_ovl=None
    max_ovl_voxel=0
    for j_ in contact_index:
        j=j_[0]
        if j==i:
            continue
        if if_closed_loop(i,j):
            continue
        voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
        ovl_voxel=(voxel_border[0,1]-voxel_border[0,0])*(voxel_border[0,3]-voxel_border[0,2])*(voxel_border[0,5]-voxel_border[0,4])
        if ovl_voxel>max_ovl_voxel:
            max_ovl_voxel=ovl_voxel
            max_ovl=j
    if max_ovl==None:
        lock.acquire()
        if_tile_being_process[i]=False
        lock.release()
        return tuple(0,0,np.zeros(3))
    j=max_ovl
    print(i,j,max_ovl_voxel)
    img1=import_img(img_path,i,dim_elem_num)
    img2=import_img(img_path,j,dim_elem_num)
    voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
    xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,voxel_border,voxel_range,step)
    lock.acquire()
    if_tile_stitched[i]=True
    if_tile_being_process[i]=False
    lock.release()
    return tuple(i,j,np.array(xyz_shift))
    

def if_closed_loop(i,j):
    while(j!=-1):
        if j==i:
            return True
        j=tile_pos_index[j]
    return False

def done(res):
    global tile_pos_index,tile_pos_stitch
    a=res.result()
    print(a)
    i,j=a[0],a[1]
    tile_pos_index[i]=j
    tile_pos_stitch[i,:]=a[3]*voxel_len  
"""
def run_multiprocess(lock,if_tile_stitched,if_tile_being_process,img_path,dim_elem_num,dim_len,voxel_len,tile_pos,voxel_range,step,tile_pos_index,tile_pos_stitch):
    print(multiprocessing.current_process().name)
    while(False in if_tile_stitched):
        lock.acquire()
        usable_index=[index for index,i in enumerate(if_tile_stitched or if_tile_being_process) if i==False]
        i=usable_index[0]
        if_tile_being_process[i]=True
        lock.release()
        contact_index=np.argwhere(tile_contact[i,:])
        max_ovl=None
        max_ovl_voxel=0
        for j_ in contact_index:
            j=j_[0]
            if j==i:
                continue
            if if_closed_loop(i,j):
                continue
            voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
            ovl_voxel=(voxel_border[0,1]-voxel_border[0,0])*(voxel_border[0,3]-voxel_border[0,2])*(voxel_border[0,5]-voxel_border[0,4])
            if ovl_voxel>max_ovl_voxel:
                max_ovl_voxel=ovl_voxel
                max_ovl=j
        if max_ovl==None:
            lock.acquire()
            if_tile_being_process[i]=False
            lock.release()
            continue
        j=max_ovl
        print(i,j,max_ovl_voxel)
        img1=import_img(img_path,i,dim_elem_num)
        img2=import_img(img_path,j,dim_elem_num)
        voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
        xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,voxel_border,voxel_range,step)
        lock.acquire()
        if_tile_stitched[i]=True
        if_tile_being_process[i]=False
        tile_pos_index[i]=j
        tile_pos_stitch[3*i:3*i+3]=xyz_shift*voxel_len
        lock.release()

def update_pos(tile_pos,tile_pos_stitch,tile_pos_index):
    '''
    this function updates positions of all tiles after being stitched
    return - array, size is the same as tile_pos
    tile_pos - array, the origin positions
    tile_pos_stitch - array, the position shift
    tile_pos_index - linspace(dtype=int), the index of reference tile
    '''
    tile_len=tile_pos.shape[0]
    for i in range(tile_len):
        j=tile_pos_index[i]
        if j==-1 or j==0:
            continue
        #从拼接的算法来说这个图一定没有闭环，所以这个算法一定不会陷入死循环
        while(j!=0 or j!=-1):
            tile_pos_stitch[i,:]=tile_pos_stitch[i,:]+tile_pos_stitch[j,:]
            j=tile_pos_index[j]
    return tile_pos+tile_pos_stitch

# %%
#Read xml file and extract the information of dimensions and each tile
my_xml_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G\MetaData\Region 1.xml'
parser=etree.XMLParser()
my_et=etree.parse(my_xml_path,parser=parser)

#Calculate the attributes of dimensions
dim_attrib=my_et.xpath('//Dimensions/DimensionDescription')
dim_elem_num=np.zeros(3,dtype='uint')#the quantity of voxels for each dimension
dim_len=np.zeros(3)#the length for one 3D image
for i in range(3):
    dim_elem_num[i],dim_len[i]=dim_attrib[i].attrib['NumberOfElements'],dim_attrib[i].attrib['Length']
    dim_len[i]=dim_attrib[i].attrib['Length']
voxel_len=dim_len/dim_elem_num

#Calculate the identifier and position for each tile
tile_attrib=my_et.xpath('//Attachment/Tile')
tile_len=len(tile_attrib)#the quantity of tiles
tile_field=np.zeros((tile_len,2),dtype='uint')#the identifier of each file
#(X,Y,Z) for tile_pos
tile_pos=np.zeros((tile_len,3))#the position of each file
for i in range(tile_len):
    tile_field[i,:]=[tile_attrib[i].attrib['FieldX'],tile_attrib[i].attrib['FieldY']]
    tile_pos[i,:]=[tile_attrib[i].attrib['PosX'],tile_attrib[i].attrib['PosY'],tile_attrib[i].attrib['PosZ']]

# %%
#Determine contacted tiles
tile_contact=np.zeros((tile_len,tile_len),dtype='bool')
for i in range(tile_len):
    for j in range(tile_len):
        if np.sum(np.abs(tile_pos[i,:]-tile_pos[j,:])<dim_len*1.05)==3:
            tile_contact[i,j]=True

# %%
#Run
'''
if_tile_stitched=np.zeros(tile_len,dtype='bool')#record if the tile is stitched
tile_pos_stitch=np.zeros((tile_len,3))
tile_pos_index=-np.ones(tile_len,dtype='int')
if_tile_stitched[0]=True
img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
voxel_range=[50,50,50]
step=5
while(False in if_tile_stitched):
    for i in range(tile_len):
        if if_tile_stitched[i]==True:
            continue
        img1=import_img(img_path,i,dim_elem_num)
        contact_list=np.argwhere(np.logical_and(if_tile_stitched,tile_contact[i,:]))
        #print(contact_list)
        if contact_list.size==0:
            continue
        max_ovl=None
        max_ovl_voxel=0
        for j_ in contact_list:
            j=j_[0]
            if j==i:
                continue
            voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
            print(voxel_border)
            ovl_voxel=(voxel_border[0,1]-voxel_border[0,0])*(voxel_border[0,3]-voxel_border[0,2])*(voxel_border[0,5]-voxel_border[0,4])
            if ovl_voxel>max_ovl_voxel:
                max_ovl_voxel=ovl_voxel
                max_ovl=j
        j=max_ovl
        print(i,j)
        img2=import_img(img_path,j,dim_elem_num)
        voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
        xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,voxel_border,voxel_range,step)
        tile_pos_stitch[i,:]=np.array(xyz_shift)*voxel_len
        tile_pos_index[i]=j
        if_tile_stitched[i]=True
'''
"""
if __name__=='__main__':
    img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
    voxel_range=[50,50,50]
    step=5
    if_tile_stitched=Manager().Array('i',[False for i in range(tile_len)])
    if_tile_stitched[0]=True
    if_tile_being_process=Manager().Array('i',[False for i in range(tile_len)])
    tile_pos_index=-np.ones(tile_len,dtype='int')
    tile_pos_stitch=np.zeros((tile_len,3))
    lock=Manager().RLock()
    process_num=round(0.5*multiprocessing.cpu_count())
    pool=ProcessPoolExecutor(process_num)
    print('Current processing quantities: %d'%(process_num))
    while(False in if_tile_stitched):
        one_pro=pool.submit(run_multiprocess,lock,if_tile_stitched,if_tile_being_process,img_path,dim_elem_num,dim_len,voxel_len,tile_pos,voxel_range,step)
        one_pro.add_done_callback(done)
    pool.shutdown(True)

"""
if __name__=='__main__':
    img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
    voxel_range=[50,50,50]
    step=5
    if_tile_stitched=Array(ctypes.c_bool,[False for i in range(tile_len)])
    if_tile_stitched[0]=True
    if_tile_being_process=Array(ctypes.c_bool,[False for i in range(tile_len)])
    tile_pos_index=Array('i',[-1 for i in range(tile_len)])
    tile_pos_stitch=Array('d',[0 for i in range(tile_len*3)])
    lock=multiprocessing.RLock()
    process_num=round(0.5*multiprocessing.cpu_count())
    print('Current processing quantities: %d'%(process_num))
    process_list=[]
    for i in range(process_num):
        one_pro=multiprocessing.Process(target=run_multiprocess,args=(lock,if_tile_stitched,if_tile_being_process,img_path,dim_elem_num,dim_len,voxel_len,tile_pos,voxel_range,step,tile_pos_index,tile_pos_stitch))
        #print(one_pro.Daemon)
        one_pro.start()
        process_list.append(one_pro)
    for i in process_list:
        i.join()
# Out:
# Current processing quantities: 10

# %%
#update all positions for all tiles
tile_final_pos=update_pos(tile_pos,tile_pos_stitch,tile_pos_index)
print(tile_final_pos)

# %%
tile_pos_stitch=Array('d',[0 for i in range(tile_len*3)])
tile_pos_index=Array('i',[-1 for i in range(tile_len)])
tile_pos_stitch=np.array(tile_pos_stitch).reshape(tile_len,3)
tile_pos_index=np.array(tile_pos_index,dtype='int')
np.save('tile_pos_stitch.npy',tile_pos_stitch)
np.save('tile_pos_index',tile_pos_index)

# %%
img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
img1=import_img(img_path,100,dim_elem_num)
img2=import_img(img_path,86,dim_elem_num)
voxel_border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[100,:],tile_pos[86,:])))
print(voxel_border)
s=time.time()
xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,voxel_border,[30,30,30],3)
e=time.time()
print('totally %f'%(e-s))
# Out:
# [[  0 512   0  51   0 126]
#  [  0 512 461 512   0 126]]
# -30 -30 -30
# torch.Size([21, 482, 96]) tensor(1.1924, device='cuda:0', dtype=torch.float64)
# -30 -30 -27
# torch.Size([21, 482, 99]) tensor(1.2242, device='cuda:0', dtype=torch.float64)
# -30 -30 -24
# torch.Size([21, 482, 102]) tensor(1.2199, device='cuda:0', dtype=torch.float64)
# -30 -30 -21
# torch.Size([21, 482, 105]) tensor(1.2035, device='cuda:0', dtype=torch.float64)
# -30 -30 -18
# torch.Size([21, 482, 108]) tensor(1.1918, device='cuda:0', dtype=torch.float64)
# -30 -30 -15
# torch.Size([21, 482, 111]) tensor(1.1773, device='cuda:0', dtype=torch.float64)
# -30 -30 -12
# torch.Size([21, 482, 114]) tensor(1.1745, device='cuda:0', dtype=torch.float64)
# -30 -30 -9
# torch.Size([21, 482, 117]) tensor(1.1761, device='cuda:0', dtype=torch.float64)
# -30 -30 -6
# torch.Size([21, 482, 120]) tensor(1.1600, device='cuda:0', dtype=torch.float64)
# -30 -30 -3
# torch.Size([21, 482, 123]) tensor(1.1544, device='cuda:0', dtype=torch.float64)
# -30 -30 0
# torch.Size([21, 482, 126]) tensor(1.1528, device='cuda:0', dtype=torch.float64)
# -30 -30 3
# torch.Size([21, 482, 123]) tensor(1.1550, device='cuda:0', dtype=torch.float64)
# -30 -30 6
# torch.Size([21, 482, 120]) tensor(1.1579, device='cuda:0', dtype=torch.float64)
# -30 -30 9
# torch.Size([21, 482, 117]) tensor(1.1583, device='cuda:0', dtype=torch.float64)
# -30 -30 12
# torch.Size([21, 482, 114]) tensor(1.1661, device='cuda:0', dtype=torch.float64)
# -30 -30 15
# torch.Size([21, 482, 111]) tensor(1.1668, device='cuda:0', dtype=torch.float64)
# -30 -30 18
# torch.Size([21, 482, 108]) tensor(1.1607, device='cuda:0', dtype=torch.float64)
# -30 -30 21
# torch.Size([21, 482, 105]) tensor(1.1765, device='cuda:0', dtype=torch.float64)
# -30 -30 24
# torch.Size([21, 482, 102]) tensor(1.1929, device='cuda:0', dtype=torch.float64)
# -30 -30 27
# torch.Size([21, 482, 99]) tensor(1.2102, device='cuda:0', dtype=torch.float64)
# -30 -30 30
# torch.Size([21, 482, 96]) tensor(1.2309, device='cuda:0', dtype=torch.float64)
# -30 -27 -30
# torch.Size([24, 482, 96]) tensor(1.1757, device='cuda:0', dtype=torch.float64)
# -30 -27 -27
# torch.Size([24, 482, 99]) tensor(1.2098, device='cuda:0', dtype=torch.float64)
# -30 -27 -24
# torch.Size([24, 482, 102]) tensor(1.2053, device='cuda:0', dtype=torch.float64)
# -30 -27 -21
# torch.Size([24, 482, 105]) tensor(1.1897, device='cuda:0', dtype=torch.float64)
# -30 -27 -18
# torch.Size([24, 482, 108]) tensor(1.1803, device='cuda:0', dtype=torch.float64)
# -30 -27 -15
# torch.Size([24, 482, 111]) tensor(1.1672, device='cuda:0', dtype=torch.float64)
# -30 -27 -12
# torch.Size([24, 482, 114]) tensor(1.1643, device='cuda:0', dtype=torch.float64)
# -30 -27 -9
# torch.Size([24, 482, 117]) tensor(1.1674, device='cuda:0', dtype=torch.float64)
# -30 -27 -6
# torch.Size([24, 482, 120]) tensor(1.1554, device='cuda:0', dtype=torch.float64)
# -30 -27 -3
# torch.Size([24, 482, 123]) tensor(1.1475, device='cuda:0', dtype=torch.float64)
# -30 -27 0
# torch.Size([24, 482, 126]) tensor(1.1439, device='cuda:0', dtype=torch.float64)
# -30 -27 3
# torch.Size([24, 482, 123]) tensor(1.1435, device='cuda:0', dtype=torch.float64)
# -30 -27 6
# torch.Size([24, 482, 120]) tensor(1.1494, device='cuda:0', dtype=torch.float64)
# -30 -27 9
# torch.Size([24, 482, 117]) tensor(1.1533, device='cuda:0', dtype=torch.float64)
# -30 -27 12
# torch.Size([24, 482, 114]) tensor(1.1608, device='cuda:0', dtype=torch.float64)
# -30 -27 15
# torch.Size([24, 482, 111]) tensor(1.1596, device='cuda:0', dtype=torch.float64)
# -30 -27 18
# torch.Size([24, 482, 108]) tensor(1.1543, device='cuda:0', dtype=torch.float64)
# -30 -27 21
# torch.Size([24, 482, 105]) tensor(1.1686, device='cuda:0', dtype=torch.float64)
# -30 -27 24
# torch.Size([24, 482, 102]) tensor(1.1869, device='cuda:0', dtype=torch.float64)
# -30 -27 27
# torch.Size([24, 482, 99]) tensor(1.2058, device='cuda:0', dtype=torch.float64)
# -30 -27 30
# torch.Size([24, 482, 96]) tensor(1.2265, device='cuda:0', dtype=torch.float64)
# -30 -24 -30
# torch.Size([27, 482, 96]) tensor(1.1553, device='cuda:0', dtype=torch.float64)
# -30 -24 -27
# torch.Size([27, 482, 99]) tensor(1.1897, device='cuda:0', dtype=torch.float64)
# -30 -24 -24
# torch.Size([27, 482, 102]) tensor(1.1846, device='cuda:0', dtype=torch.float64)
# -30 -24 -21
# torch.Size([27, 482, 105]) tensor(1.1679, device='cuda:0', dtype=torch.float64)
# -30 -24 -18
# torch.Size([27, 482, 108]) tensor(1.1628, device='cuda:0', dtype=torch.float64)
# -30 -24 -15
# torch.Size([27, 482, 111]) tensor(1.1537, device='cuda:0', dtype=torch.float64)
# -30 -24 -12
# torch.Size([27, 482, 114]) tensor(1.1507, device='cuda:0', dtype=torch.float64)
# -30 -24 -9
# torch.Size([27, 482, 117]) tensor(1.1534, device='cuda:0', dtype=torch.float64)
# -30 -24 -6
# torch.Size([27, 482, 120]) tensor(1.1425, device='cuda:0', dtype=torch.float64)
# -30 -24 -3
# torch.Size([27, 482, 123]) tensor(1.1341, device='cuda:0', dtype=torch.float64)
# -30 -24 0
# torch.Size([27, 482, 126]) tensor(1.1297, device='cuda:0', dtype=torch.float64)
# -30 -24 3
# torch.Size([27, 482, 123]) tensor(1.1314, device='cuda:0', dtype=torch.float64)
# -30 -24 6
# torch.Size([27, 482, 120]) tensor(1.1376, device='cuda:0', dtype=torch.float64)
# -30 -24 9
# torch.Size([27, 482, 117]) tensor(1.1414, device='cuda:0', dtype=torch.float64)
# -30 -24 12
# torch.Size([27, 482, 114]) tensor(1.1468, device='cuda:0', dtype=torch.float64)
# -30 -24 15
# torch.Size([27, 482, 111]) tensor(1.1463, device='cuda:0', dtype=torch.float64)
# -30 -24 18
# torch.Size([27, 482, 108]) tensor(1.1411, device='cuda:0', dtype=torch.float64)
# -30 -24 21
# torch.Size([27, 482, 105]) tensor(1.1535, device='cuda:0', dtype=torch.float64)
# -30 -24 24
# torch.Size([27, 482, 102]) tensor(1.1719, device='cuda:0', dtype=torch.float64)
# -30 -24 27
# torch.Size([27, 482, 99]) tensor(1.1945, device='cuda:0', dtype=torch.float64)
# -30 -24 30
# torch.Size([27, 482, 96]) tensor(1.2151, device='cuda:0', dtype=torch.float64)
# -30 -21 -30
# torch.Size([30, 482, 96]) tensor(1.1329, device='cuda:0', dtype=torch.float64)
# -30 -21 -27
# torch.Size([30, 482, 99]) tensor(1.1665, device='cuda:0', dtype=torch.float64)
# -30 -21 -24
# torch.Size([30, 482, 102]) tensor(1.1627, device='cuda:0', dtype=torch.float64)
# -30 -21 -21
# torch.Size([30, 482, 105]) tensor(1.1441, device='cuda:0', dtype=torch.float64)
# -30 -21 -18
# torch.Size([30, 482, 108]) tensor(1.1405, device='cuda:0', dtype=torch.float64)
# -30 -21 -15
# torch.Size([30, 482, 111]) tensor(1.1384, device='cuda:0', dtype=torch.float64)
# -30 -21 -12
# torch.Size([30, 482, 114]) tensor(1.1346, device='cuda:0', dtype=torch.float64)
# -30 -21 -9
# torch.Size([30, 482, 117]) tensor(1.1343, device='cuda:0', dtype=torch.float64)
# -30 -21 -6
# torch.Size([30, 482, 120]) tensor(1.1234, device='cuda:0', dtype=torch.float64)
# -30 -21 -3
# torch.Size([30, 482, 123]) tensor(1.1166, device='cuda:0', dtype=torch.float64)
# -30 -21 0
# torch.Size([30, 482, 126]) tensor(1.1138, device='cuda:0', dtype=torch.float64)
# -30 -21 3
# torch.Size([30, 482, 123]) tensor(1.1187, device='cuda:0', dtype=torch.float64)
# -30 -21 6
# torch.Size([30, 482, 120]) tensor(1.1235, device='cuda:0', dtype=torch.float64)
# -30 -21 9
# torch.Size([30, 482, 117]) tensor(1.1264, device='cuda:0', dtype=torch.float64)
# -30 -21 12
# torch.Size([30, 482, 114]) tensor(1.1324, device='cuda:0', dtype=torch.float64)
# -30 -21 15
# torch.Size([30, 482, 111]) tensor(1.1305, device='cuda:0', dtype=torch.float64)
# -30 -21 18
# torch.Size([30, 482, 108]) tensor(1.1230, device='cuda:0', dtype=torch.float64)
# -30 -21 21
# torch.Size([30, 482, 105]) tensor(1.1349, device='cuda:0', dtype=torch.float64)
# -30 -21 24
# torch.Size([30, 482, 102]) tensor(1.1529, device='cuda:0', dtype=torch.float64)
# -30 -21 27
# torch.Size([30, 482, 99]) tensor(1.1781, device='cuda:0', dtype=torch.float64)
# -30 -21 30
# torch.Size([30, 482, 96]) tensor(1.1980, device='cuda:0', dtype=torch.float64)
# -30 -18 -30
# torch.Size([33, 482, 96]) tensor(1.1131, device='cuda:0', dtype=torch.float64)
# -30 -18 -27
# torch.Size([33, 482, 99]) tensor(1.1451, device='cuda:0', dtype=torch.float64)
# -30 -18 -24
# torch.Size([33, 482, 102]) tensor(1.1412, device='cuda:0', dtype=torch.float64)
# -30 -18 -21
# torch.Size([33, 482, 105]) tensor(1.1226, device='cuda:0', dtype=torch.float64)
# -30 -18 -18
# torch.Size([33, 482, 108]) tensor(1.1191, device='cuda:0', dtype=torch.float64)
# -30 -18 -15
# torch.Size([33, 482, 111]) tensor(1.1221, device='cuda:0', dtype=torch.float64)
# -30 -18 -12
# torch.Size([33, 482, 114]) tensor(1.1177, device='cuda:0', dtype=torch.float64)
# -30 -18 -9
# torch.Size([33, 482, 117]) tensor(1.1157, device='cuda:0', dtype=torch.float64)
# -30 -18 -6
# torch.Size([33, 482, 120]) tensor(1.1073, device='cuda:0', dtype=torch.float64)
# -30 -18 -3
# torch.Size([33, 482, 123]) tensor(1.0994, device='cuda:0', dtype=torch.float64)
# -30 -18 0
# torch.Size([33, 482, 126]) tensor(1.0999, device='cuda:0', dtype=torch.float64)
# -30 -18 3
# torch.Size([33, 482, 123]) tensor(1.1057, device='cuda:0', dtype=torch.float64)
# -30 -18 6
# torch.Size([33, 482, 120]) tensor(1.1086, device='cuda:0', dtype=torch.float64)
# -30 -18 9
# torch.Size([33, 482, 117]) tensor(1.1133, device='cuda:0', dtype=torch.float64)
# -30 -18 12
# torch.Size([33, 482, 114]) tensor(1.1185, device='cuda:0', dtype=torch.float64)
# -30 -18 15
# torch.Size([33, 482, 111]) tensor(1.1175, device='cuda:0', dtype=torch.float64)
# -30 -18 18
# torch.Size([33, 482, 108]) tensor(1.1094, device='cuda:0', dtype=torch.float64)
# -30 -18 21
# torch.Size([33, 482, 105]) tensor(1.1194, device='cuda:0', dtype=torch.float64)
# -30 -18 24
# torch.Size([33, 482, 102]) tensor(1.1386, device='cuda:0', dtype=torch.float64)
# -30 -18 27
# torch.Size([33, 482, 99]) tensor(1.1634, device='cuda:0', dtype=torch.float64)
# -30 -18 30
# torch.Size([33, 482, 96]) tensor(1.1856, device='cuda:0', dtype=torch.float64)
# -30 -15 -30
# torch.Size([36, 482, 96]) tensor(1.0969, device='cuda:0', dtype=torch.float64)
# -30 -15 -27
# torch.Size([36, 482, 99]) tensor(1.1260, device='cuda:0', dtype=torch.float64)
# -30 -15 -24
# torch.Size([36, 482, 102]) tensor(1.1203, device='cuda:0', dtype=torch.float64)
# -30 -15 -21
# torch.Size([36, 482, 105]) tensor(1.1003, device='cuda:0', dtype=torch.float64)
# -30 -15 -18
# torch.Size([36, 482, 108]) tensor(1.0989, device='cuda:0', dtype=torch.float64)
# -30 -15 -15
# torch.Size([36, 482, 111]) tensor(1.1066, device='cuda:0', dtype=torch.float64)
# -30 -15 -12
# torch.Size([36, 482, 114]) tensor(1.1030, device='cuda:0', dtype=torch.float64)
# -30 -15 -9
# torch.Size([36, 482, 117]) tensor(1.1000, device='cuda:0', dtype=torch.float64)
# -30 -15 -6
# torch.Size([36, 482, 120]) tensor(1.0925, device='cuda:0', dtype=torch.float64)
# -30 -15 -3
# torch.Size([36, 482, 123]) tensor(1.0858, device='cuda:0', dtype=torch.float64)
# -30 -15 0
# torch.Size([36, 482, 126]) tensor(1.0883, device='cuda:0', dtype=torch.float64)
# -30 -15 3
# torch.Size([36, 482, 123]) tensor(1.0942, device='cuda:0', dtype=torch.float64)
# -30 -15 6
# torch.Size([36, 482, 120]) tensor(1.0955, device='cuda:0', dtype=torch.float64)
# -30 -15 9
# torch.Size([36, 482, 117]) tensor(1.1025, device='cuda:0', dtype=torch.float64)
# -30 -15 12
# torch.Size([36, 482, 114]) tensor(1.1084, device='cuda:0', dtype=torch.float64)
# -30 -15 15
# torch.Size([36, 482, 111]) tensor(1.1088, device='cuda:0', dtype=torch.float64)
# -30 -15 18
# torch.Size([36, 482, 108]) tensor(1.1005, device='cuda:0', dtype=torch.float64)
# -30 -15 21
# torch.Size([36, 482, 105]) tensor(1.1084, device='cuda:0', dtype=torch.float64)
# -30 -15 24
# torch.Size([36, 482, 102]) tensor(1.1266, device='cuda:0', dtype=torch.float64)
# -30 -15 27
# torch.Size([36, 482, 99]) tensor(1.1512, device='cuda:0', dtype=torch.float64)
# -30 -15 30
# torch.Size([36, 482, 96]) tensor(1.1716, device='cuda:0', dtype=torch.float64)
# -30 -12 -30
# torch.Size([39, 482, 96]) tensor(1.0864, device='cuda:0', dtype=torch.float64)
# -30 -12 -27
# torch.Size([39, 482, 99]) tensor(1.1108, device='cuda:0', dtype=torch.float64)
# -30 -12 -24
# torch.Size([39, 482, 102]) tensor(1.1025, device='cuda:0', dtype=torch.float64)
# -30 -12 -21
# torch.Size([39, 482, 105]) tensor(1.0826, device='cuda:0', dtype=torch.float64)
# -30 -12 -18
# torch.Size([39, 482, 108]) tensor(1.0823, device='cuda:0', dtype=torch.float64)
# -30 -12 -15
# torch.Size([39, 482, 111]) tensor(1.0940, device='cuda:0', dtype=torch.float64)
# -30 -12 -12
# torch.Size([39, 482, 114]) tensor(1.0917, device='cuda:0', dtype=torch.float64)
# -30 -12 -9
# torch.Size([39, 482, 117]) tensor(1.0845, device='cuda:0', dtype=torch.float64)
# -30 -12 -6
# torch.Size([39, 482, 120]) tensor(1.0744, device='cuda:0', dtype=torch.float64)
# -30 -12 -3
# torch.Size([39, 482, 123]) tensor(1.0679, device='cuda:0', dtype=torch.float64)
# -30 -12 0
# torch.Size([39, 482, 126]) tensor(1.0743, device='cuda:0', dtype=torch.float64)
# -30 -12 3
# torch.Size([39, 482, 123]) tensor(1.0807, device='cuda:0', dtype=torch.float64)
# -30 -12 6
# torch.Size([39, 482, 120]) tensor(1.0822, device='cuda:0', dtype=torch.float64)
# -30 -12 9
# torch.Size([39, 482, 117]) tensor(1.0922, device='cuda:0', dtype=torch.float64)
# -30 -12 12
# torch.Size([39, 482, 114]) tensor(1.1018, device='cuda:0', dtype=torch.float64)
# -30 -12 15
# torch.Size([39, 482, 111]) tensor(1.1006, device='cuda:0', dtype=torch.float64)
# -30 -12 18
# torch.Size([39, 482, 108]) tensor(1.0928, device='cuda:0', dtype=torch.float64)
# -30 -12 21
# torch.Size([39, 482, 105]) tensor(1.0998, device='cuda:0', dtype=torch.float64)
# -30 -12 24
# torch.Size([39, 482, 102]) tensor(1.1160, device='cuda:0', dtype=torch.float64)
# -30 -12 27
# torch.Size([39, 482, 99]) tensor(1.1390, device='cuda:0', dtype=torch.float64)
# -30 -12 30
# torch.Size([39, 482, 96]) tensor(1.1596, device='cuda:0', dtype=torch.float64)
# -30 -9 -30
# torch.Size([42, 482, 96]) tensor(1.0785, device='cuda:0', dtype=torch.float64)
# -30 -9 -27
# torch.Size([42, 482, 99]) tensor(1.0963, device='cuda:0', dtype=torch.float64)
# -30 -9 -24
# torch.Size([42, 482, 102]) tensor(1.0893, device='cuda:0', dtype=torch.float64)
# -30 -9 -21
# torch.Size([42, 482, 105]) tensor(1.0698, device='cuda:0', dtype=torch.float64)
# -30 -9 -18
# torch.Size([42, 482, 108]) tensor(1.0706, device='cuda:0', dtype=torch.float64)
# -30 -9 -15
# torch.Size([42, 482, 111]) tensor(1.0855, device='cuda:0', dtype=torch.float64)
# -30 -9 -12
# torch.Size([42, 482, 114]) tensor(1.0823, device='cuda:0', dtype=torch.float64)
# -30 -9 -9
# torch.Size([42, 482, 117]) tensor(1.0711, device='cuda:0', dtype=torch.float64)
# -30 -9 -6
# torch.Size([42, 482, 120]) tensor(1.0581, device='cuda:0', dtype=torch.float64)
# -30 -9 -3
# torch.Size([42, 482, 123]) tensor(1.0541, device='cuda:0', dtype=torch.float64)
# -30 -9 0
# torch.Size([42, 482, 126]) tensor(1.0621, device='cuda:0', dtype=torch.float64)
# -30 -9 3
# torch.Size([42, 482, 123]) tensor(1.0692, device='cuda:0', dtype=torch.float64)
# -30 -9 6
# torch.Size([42, 482, 120]) tensor(1.0732, device='cuda:0', dtype=torch.float64)
# -30 -9 9
# torch.Size([42, 482, 117]) tensor(1.0855, device='cuda:0', dtype=torch.float64)
# -30 -9 12
# torch.Size([42, 482, 114]) tensor(1.0949, device='cuda:0', dtype=torch.float64)
# -30 -9 15
# torch.Size([42, 482, 111]) tensor(1.0956, device='cuda:0', dtype=torch.float64)
# -30 -9 18
# torch.Size([42, 482, 108]) tensor(1.0877, device='cuda:0', dtype=torch.float64)
# -30 -9 21
# torch.Size([42, 482, 105]) tensor(1.0940, device='cuda:0', dtype=torch.float64)
# -30 -9 24
# torch.Size([42, 482, 102]) tensor(1.1066, device='cuda:0', dtype=torch.float64)
# -30 -9 27
# torch.Size([42, 482, 99]) tensor(1.1301, device='cuda:0', dtype=torch.float64)
# -30 -9 30
# torch.Size([42, 482, 96]) tensor(1.1509, device='cuda:0', dtype=torch.float64)
# -30 -6 -30
# torch.Size([45, 482, 96]) tensor(1.0728, device='cuda:0', dtype=torch.float64)
# -30 -6 -27
# torch.Size([45, 482, 99]) tensor(1.0866, device='cuda:0', dtype=torch.float64)
# -30 -6 -24
# torch.Size([45, 482, 102]) tensor(1.0804, device='cuda:0', dtype=torch.float64)
# -30 -6 -21
# torch.Size([45, 482, 105]) tensor(1.0635, device='cuda:0', dtype=torch.float64)
# -30 -6 -18
# torch.Size([45, 482, 108]) tensor(1.0665, device='cuda:0', dtype=torch.float64)
# -30 -6 -15
# torch.Size([45, 482, 111]) tensor(1.0798, device='cuda:0', dtype=torch.float64)
# -30 -6 -12
# torch.Size([45, 482, 114]) tensor(1.0755, device='cuda:0', dtype=torch.float64)
# -30 -6 -9
# torch.Size([45, 482, 117]) tensor(1.0611, device='cuda:0', dtype=torch.float64)
# -30 -6 -6
# torch.Size([45, 482, 120]) tensor(1.0515, device='cuda:0', dtype=torch.float64)
# -30 -6 -3
# torch.Size([45, 482, 123]) tensor(1.0471, device='cuda:0', dtype=torch.float64)
# -30 -6 0
# torch.Size([45, 482, 126]) tensor(1.0519, device='cuda:0', dtype=torch.float64)
# -30 -6 3
# torch.Size([45, 482, 123]) tensor(1.0621, device='cuda:0', dtype=torch.float64)
# -30 -6 6
# torch.Size([45, 482, 120]) tensor(1.0679, device='cuda:0', dtype=torch.float64)
# -30 -6 9
# torch.Size([45, 482, 117]) tensor(1.0805, device='cuda:0', dtype=torch.float64)
# -30 -6 12
# torch.Size([45, 482, 114]) tensor(1.0891, device='cuda:0', dtype=torch.float64)
# -30 -6 15
# torch.Size([45, 482, 111]) tensor(1.0909, device='cuda:0', dtype=torch.float64)
# -30 -6 18
# torch.Size([45, 482, 108]) tensor(1.0868, device='cuda:0', dtype=torch.float64)
# -30 -6 21
# torch.Size([45, 482, 105]) tensor(1.0905, device='cuda:0', dtype=torch.float64)
# -30 -6 24
# torch.Size([45, 482, 102]) tensor(1.1015, device='cuda:0', dtype=torch.float64)
# -30 -6 27
# torch.Size([45, 482, 99]) tensor(1.1247, device='cuda:0', dtype=torch.float64)
# -30 -6 30
# torch.Size([45, 482, 96]) tensor(1.1436, device='cuda:0', dtype=torch.float64)
# -30 -3 -30
# torch.Size([48, 482, 96]) tensor(1.0707, device='cuda:0', dtype=torch.float64)
# -30 -3 -27
# torch.Size([48, 482, 99]) tensor(1.0816, device='cuda:0', dtype=torch.float64)
# -30 -3 -24
# torch.Size([48, 482, 102]) tensor(1.0771, device='cuda:0', dtype=torch.float64)
# -30 -3 -21
# torch.Size([48, 482, 105]) tensor(1.0618, device='cuda:0', dtype=torch.float64)
# -30 -3 -18
# torch.Size([48, 482, 108]) tensor(1.0641, device='cuda:0', dtype=torch.float64)
# -30 -3 -15
# torch.Size([48, 482, 111]) tensor(1.0752, device='cuda:0', dtype=torch.float64)
# -30 -3 -12
# torch.Size([48, 482, 114]) tensor(1.0713, device='cuda:0', dtype=torch.float64)
# -30 -3 -9
# torch.Size([48, 482, 117]) tensor(1.0587, device='cuda:0', dtype=torch.float64)
# -30 -3 -6
# torch.Size([48, 482, 120]) tensor(1.0468, device='cuda:0', dtype=torch.float64)
# -30 -3 -3
# torch.Size([48, 482, 123]) tensor(1.0389, device='cuda:0', dtype=torch.float64)
# -30 -3 0
# torch.Size([48, 482, 126]) tensor(1.0437, device='cuda:0', dtype=torch.float64)
# -30 -3 3
# torch.Size([48, 482, 123]) tensor(1.0557, device='cuda:0', dtype=torch.float64)
# -30 -3 6
# torch.Size([48, 482, 120]) tensor(1.0635, device='cuda:0', dtype=torch.float64)
# -30 -3 9
# torch.Size([48, 482, 117]) tensor(1.0763, device='cuda:0', dtype=torch.float64)
# -30 -3 12
# torch.Size([48, 482, 114]) tensor(1.0849, device='cuda:0', dtype=torch.float64)
# -30 -3 15
# torch.Size([48, 482, 111]) tensor(1.0888, device='cuda:0', dtype=torch.float64)
# -30 -3 18
# torch.Size([48, 482, 108]) tensor(1.0870, device='cuda:0', dtype=torch.float64)
# -30 -3 21
# torch.Size([48, 482, 105]) tensor(1.0896, device='cuda:0', dtype=torch.float64)
# -30 -3 24
# torch.Size([48, 482, 102]) tensor(1.1012, device='cuda:0', dtype=torch.float64)
# -30 -3 27
# torch.Size([48, 482, 99]) tensor(1.1220, device='cuda:0', dtype=torch.float64)
# -30 -3 30
# torch.Size([48, 482, 96]) tensor(1.1379, device='cuda:0', dtype=torch.float64)
# -30 0 -30
# torch.Size([51, 482, 96]) tensor(1.0691, device='cuda:0', dtype=torch.float64)
# -30 0 -27
# torch.Size([51, 482, 99]) tensor(1.0773, device='cuda:0', dtype=torch.float64)
# -30 0 -24
# torch.Size([51, 482, 102]) tensor(1.0737, device='cuda:0', dtype=torch.float64)
# -30 0 -21
# torch.Size([51, 482, 105]) tensor(1.0600, device='cuda:0', dtype=torch.float64)
# -30 0 -18
# torch.Size([51, 482, 108]) tensor(1.0611, device='cuda:0', dtype=torch.float64)
# -30 0 -15
# torch.Size([51, 482, 111]) tensor(1.0708, device='cuda:0', dtype=torch.float64)
# -30 0 -12
# torch.Size([51, 482, 114]) tensor(1.0696, device='cuda:0', dtype=torch.float64)
# -30 0 -9
# torch.Size([51, 482, 117]) tensor(1.0555, device='cuda:0', dtype=torch.float64)
# -30 0 -6
# torch.Size([51, 482, 120]) tensor(1.0414, device='cuda:0', dtype=torch.float64)
# -30 0 -3
# torch.Size([51, 482, 123]) tensor(1.0316, device='cuda:0', dtype=torch.float64)
# -30 0 0
# torch.Size([51, 482, 126]) tensor(1.0382, device='cuda:0', dtype=torch.float64)
# -30 0 3
# torch.Size([51, 482, 123]) tensor(1.0511, device='cuda:0', dtype=torch.float64)
# -30 0 6
# torch.Size([51, 482, 120]) tensor(1.0598, device='cuda:0', dtype=torch.float64)
# -30 0 9
# torch.Size([51, 482, 117]) tensor(1.0726, device='cuda:0', dtype=torch.float64)
# -30 0 12
# torch.Size([51, 482, 114]) tensor(1.0806, device='cuda:0', dtype=torch.float64)
# -30 0 15
# torch.Size([51, 482, 111]) tensor(1.0872, device='cuda:0', dtype=torch.float64)
# -30 0 18
# torch.Size([51, 482, 108]) tensor(1.0883, device='cuda:0', dtype=torch.float64)
# -30 0 21
# torch.Size([51, 482, 105]) tensor(1.0921, device='cuda:0', dtype=torch.float64)
# -30 0 24
# torch.Size([51, 482, 102]) tensor(1.1028, device='cuda:0', dtype=torch.float64)
# -30 0 27
# torch.Size([51, 482, 99]) tensor(1.1210, device='cuda:0', dtype=torch.float64)
# -30 0 30
# torch.Size([51, 482, 96]) tensor(1.1353, device='cuda:0', dtype=torch.float64)
# -30 3 -30
# torch.Size([54, 482, 96]) tensor(1.0688, device='cuda:0', dtype=torch.float64)
# -30 3 -27
# torch.Size([54, 482, 99]) tensor(1.0757, device='cuda:0', dtype=torch.float64)
# -30 3 -24
# torch.Size([54, 482, 102]) tensor(1.0731, device='cuda:0', dtype=torch.float64)
# -30 3 -21
# torch.Size([54, 482, 105]) tensor(1.0623, device='cuda:0', dtype=torch.float64)
# -30 3 -18
# torch.Size([54, 482, 108]) tensor(1.0613, device='cuda:0', dtype=torch.float64)
# -30 3 -15
# torch.Size([54, 482, 111]) tensor(1.0700, device='cuda:0', dtype=torch.float64)
# -30 3 -12
# torch.Size([54, 482, 114]) tensor(1.0681, device='cuda:0', dtype=torch.float64)
# -30 3 -9
# torch.Size([54, 482, 117]) tensor(1.0536, device='cuda:0', dtype=torch.float64)
# -30 3 -6
# torch.Size([54, 482, 120]) tensor(1.0382, device='cuda:0', dtype=torch.float64)
# -30 3 -3
# torch.Size([54, 482, 123]) tensor(1.0286, device='cuda:0', dtype=torch.float64)
# -30 3 0
# torch.Size([54, 482, 126]) tensor(1.0353, device='cuda:0', dtype=torch.float64)
# -30 3 3
# torch.Size([54, 482, 123]) tensor(1.0490, device='cuda:0', dtype=torch.float64)
# -30 3 6
# torch.Size([54, 482, 120]) tensor(1.0591, device='cuda:0', dtype=torch.float64)
# -30 3 9
# torch.Size([54, 482, 117]) tensor(1.0707, device='cuda:0', dtype=torch.float64)
# -30 3 12
# torch.Size([54, 482, 114]) tensor(1.0799, device='cuda:0', dtype=torch.float64)
# -30 3 15
# torch.Size([54, 482, 111]) tensor(1.0869, device='cuda:0', dtype=torch.float64)
# -30 3 18
# torch.Size([54, 482, 108]) tensor(1.0905, device='cuda:0', dtype=torch.float64)
# -30 3 21
# torch.Size([54, 482, 105]) tensor(1.0954, device='cuda:0', dtype=torch.float64)
# -30 3 24
# torch.Size([54, 482, 102]) tensor(1.1040, device='cuda:0', dtype=torch.float64)
# -30 3 27
# torch.Size([54, 482, 99]) tensor(1.1209, device='cuda:0', dtype=torch.float64)
# -30 3 30
# torch.Size([54, 482, 96]) tensor(1.1364, device='cuda:0', dtype=torch.float64)
# -30 6 -30
# torch.Size([57, 482, 96]) tensor(1.0691, device='cuda:0', dtype=torch.float64)
# -30 6 -27
# torch.Size([57, 482, 99]) tensor(1.0773, device='cuda:0', dtype=torch.float64)
# -30 6 -24
# torch.Size([57, 482, 102]) tensor(1.0763, device='cuda:0', dtype=torch.float64)
# -30 6 -21
# torch.Size([57, 482, 105]) tensor(1.0668, device='cuda:0', dtype=torch.float64)
# -30 6 -18
# torch.Size([57, 482, 108]) tensor(1.0640, device='cuda:0', dtype=torch.float64)
# -30 6 -15
# torch.Size([57, 482, 111]) tensor(1.0700, device='cuda:0', dtype=torch.float64)
# -30 6 -12
# torch.Size([57, 482, 114]) tensor(1.0690, device='cuda:0', dtype=torch.float64)
# -30 6 -9
# torch.Size([57, 482, 117]) tensor(1.0532, device='cuda:0', dtype=torch.float64)
# -30 6 -6
# torch.Size([57, 482, 120]) tensor(1.0375, device='cuda:0', dtype=torch.float64)
# -30 6 -3
# torch.Size([57, 482, 123]) tensor(1.0285, device='cuda:0', dtype=torch.float64)
# -30 6 0
# torch.Size([57, 482, 126]) tensor(1.0358, device='cuda:0', dtype=torch.float64)
# -30 6 3
# torch.Size([57, 482, 123]) tensor(1.0489, device='cuda:0', dtype=torch.float64)
# -30 6 6
# torch.Size([57, 482, 120]) tensor(1.0590, device='cuda:0', dtype=torch.float64)
# -30 6 9
# torch.Size([57, 482, 117]) tensor(1.0702, device='cuda:0', dtype=torch.float64)
# -30 6 12
# torch.Size([57, 482, 114]) tensor(1.0802, device='cuda:0', dtype=torch.float64)
# -30 6 15
# torch.Size([57, 482, 111]) tensor(1.0886, device='cuda:0', dtype=torch.float64)
# -30 6 18
# torch.Size([57, 482, 108]) tensor(1.0938, device='cuda:0', dtype=torch.float64)
# -30 6 21
# torch.Size([57, 482, 105]) tensor(1.0986, device='cuda:0', dtype=torch.float64)
# -30 6 24
# torch.Size([57, 482, 102]) tensor(1.1060, device='cuda:0', dtype=torch.float64)
# -30 6 27
# torch.Size([57, 482, 99]) tensor(1.1239, device='cuda:0', dtype=torch.float64)
# -30 6 30
# torch.Size([57, 482, 96]) tensor(1.1397, device='cuda:0', dtype=torch.float64)
# -30 9 -30
# torch.Size([60, 482, 96]) tensor(1.0705, device='cuda:0', dtype=torch.float64)
# -30 9 -27
# torch.Size([60, 482, 99]) tensor(1.0796, device='cuda:0', dtype=torch.float64)
# -30 9 -24
# torch.Size([60, 482, 102]) tensor(1.0800, device='cuda:0', dtype=torch.float64)
# -30 9 -21
# torch.Size([60, 482, 105]) tensor(1.0729, device='cuda:0', dtype=torch.float64)
# -30 9 -18
# torch.Size([60, 482, 108]) tensor(1.0679, device='cuda:0', dtype=torch.float64)
# -30 9 -15
# torch.Size([60, 482, 111]) tensor(1.0743, device='cuda:0', dtype=torch.float64)
# -30 9 -12
# torch.Size([60, 482, 114]) tensor(1.0712, device='cuda:0', dtype=torch.float64)
# -30 9 -9
# torch.Size([60, 482, 117]) tensor(1.0541, device='cuda:0', dtype=torch.float64)
# -30 9 -6
# torch.Size([60, 482, 120]) tensor(1.0356, device='cuda:0', dtype=torch.float64)
# -30 9 -3
# torch.Size([60, 482, 123]) tensor(1.0275, device='cuda:0', dtype=torch.float64)
# -30 9 0
# torch.Size([60, 482, 126]) tensor(1.0353, device='cuda:0', dtype=torch.float64)
# -30 9 3
# torch.Size([60, 482, 123]) tensor(1.0484, device='cuda:0', dtype=torch.float64)
# -30 9 6
# torch.Size([60, 482, 120]) tensor(1.0593, device='cuda:0', dtype=torch.float64)
# -30 9 9
# torch.Size([60, 482, 117]) tensor(1.0723, device='cuda:0', dtype=torch.float64)
# -30 9 12
# torch.Size([60, 482, 114]) tensor(1.0830, device='cuda:0', dtype=torch.float64)
# -30 9 15
# torch.Size([60, 482, 111]) tensor(1.0907, device='cuda:0', dtype=torch.float64)
# -30 9 18
# torch.Size([60, 482, 108]) tensor(1.0964, device='cuda:0', dtype=torch.float64)
# -30 9 21
# torch.Size([60, 482, 105]) tensor(1.1015, device='cuda:0', dtype=torch.float64)
# -30 9 24
# torch.Size([60, 482, 102]) tensor(1.1100, device='cuda:0', dtype=torch.float64)
# -30 9 27
# torch.Size([60, 482, 99]) tensor(1.1293, device='cuda:0', dtype=torch.float64)
# -30 9 30
# torch.Size([60, 482, 96]) tensor(1.1421, device='cuda:0', dtype=torch.float64)
# -30 12 -30
# torch.Size([63, 482, 96]) tensor(1.0731, device='cuda:0', dtype=torch.float64)
# -30 12 -27
# torch.Size([63, 482, 99]) tensor(1.0833, device='cuda:0', dtype=torch.float64)
# -30 12 -24
# torch.Size([63, 482, 102]) tensor(1.0844, device='cuda:0', dtype=torch.float64)
# -30 12 -21
# torch.Size([63, 482, 105]) tensor(1.0789, device='cuda:0', dtype=torch.float64)
# -30 12 -18
# torch.Size([63, 482, 108]) tensor(1.0734, device='cuda:0', dtype=torch.float64)
# -30 12 -15
# torch.Size([63, 482, 111]) tensor(1.0774, device='cuda:0', dtype=torch.float64)
# -30 12 -12
# torch.Size([63, 482, 114]) tensor(1.0709, device='cuda:0', dtype=torch.float64)
# -30 12 -9
# torch.Size([63, 482, 117]) tensor(1.0560, device='cuda:0', dtype=torch.float64)
# -30 12 -6
# torch.Size([63, 482, 120]) tensor(1.0351, device='cuda:0', dtype=torch.float64)
# -30 12 -3
# torch.Size([63, 482, 123]) tensor(1.0254, device='cuda:0', dtype=torch.float64)
# -30 12 0
# torch.Size([63, 482, 126]) tensor(1.0328, device='cuda:0', dtype=torch.float64)
# -30 12 3
# torch.Size([63, 482, 123]) tensor(1.0455, device='cuda:0', dtype=torch.float64)
# -30 12 6
# torch.Size([63, 482, 120]) tensor(1.0592, device='cuda:0', dtype=torch.float64)
# -30 12 9
# torch.Size([63, 482, 117]) tensor(1.0740, device='cuda:0', dtype=torch.float64)
# -30 12 12
# torch.Size([63, 482, 114]) tensor(1.0859, device='cuda:0', dtype=torch.float64)
# -30 12 15
# torch.Size([63, 482, 111]) tensor(1.0923, device='cuda:0', dtype=torch.float64)
# -30 12 18
# torch.Size([63, 482, 108]) tensor(1.0987, device='cuda:0', dtype=torch.float64)
# -30 12 21
# torch.Size([63, 482, 105]) tensor(1.1051, device='cuda:0', dtype=torch.float64)
# -30 12 24
# torch.Size([63, 482, 102]) tensor(1.1144, device='cuda:0', dtype=torch.float64)
# -30 12 27
# torch.Size([63, 482, 99]) tensor(1.1327, device='cuda:0', dtype=torch.float64)
# -30 12 30
# torch.Size([63, 482, 96]) tensor(1.1441, device='cuda:0', dtype=torch.float64)
# -30 15 -30
# torch.Size([66, 482, 96]) tensor(1.0786, device='cuda:0', dtype=torch.float64)
# -30 15 -27
# torch.Size([66, 482, 99]) tensor(1.0881, device='cuda:0', dtype=torch.float64)
# -30 15 -24
# torch.Size([66, 482, 102]) tensor(1.0913, device='cuda:0', dtype=torch.float64)
# -30 15 -21
# torch.Size([66, 482, 105]) tensor(1.0853, device='cuda:0', dtype=torch.float64)
# -30 15 -18
# torch.Size([66, 482, 108]) tensor(1.0781, device='cuda:0', dtype=torch.float64)
# -30 15 -15
# torch.Size([66, 482, 111]) tensor(1.0793, device='cuda:0', dtype=torch.float64)
# -30 15 -12
# torch.Size([66, 482, 114]) tensor(1.0734, device='cuda:0', dtype=torch.float64)
# -30 15 -9
# torch.Size([66, 482, 117]) tensor(1.0586, device='cuda:0', dtype=torch.float64)
# -30 15 -6
# torch.Size([66, 482, 120]) tensor(1.0365, device='cuda:0', dtype=torch.float64)
# -30 15 -3
# torch.Size([66, 482, 123]) tensor(1.0254, device='cuda:0', dtype=torch.float64)
# -30 15 0
# torch.Size([66, 482, 126]) tensor(1.0300, device='cuda:0', dtype=torch.float64)
# -30 15 3
# torch.Size([66, 482, 123]) tensor(1.0440, device='cuda:0', dtype=torch.float64)
# -30 15 6
# torch.Size([66, 482, 120]) tensor(1.0602, device='cuda:0', dtype=torch.float64)
# -30 15 9
# torch.Size([66, 482, 117]) tensor(1.0760, device='cuda:0', dtype=torch.float64)
# -30 15 12
# torch.Size([66, 482, 114]) tensor(1.0888, device='cuda:0', dtype=torch.float64)
# -30 15 15
# torch.Size([66, 482, 111]) tensor(1.0952, device='cuda:0', dtype=torch.float64)
# -30 15 18
# torch.Size([66, 482, 108]) tensor(1.1020, device='cuda:0', dtype=torch.float64)
# -30 15 21
# torch.Size([66, 482, 105]) tensor(1.1083, device='cuda:0', dtype=torch.float64)
# -30 15 24
# torch.Size([66, 482, 102]) tensor(1.1186, device='cuda:0', dtype=torch.float64)
# -30 15 27
# torch.Size([66, 482, 99]) tensor(1.1358, device='cuda:0', dtype=torch.float64)
# -30 15 30
# torch.Size([66, 482, 96]) tensor(1.1457, device='cuda:0', dtype=torch.float64)
# -30 18 -30
# torch.Size([69, 482, 96]) tensor(1.0857, device='cuda:0', dtype=torch.float64)
# -30 18 -27
# torch.Size([69, 482, 99]) tensor(1.0948, device='cuda:0', dtype=torch.float64)
# -30 18 -24
# torch.Size([69, 482, 102]) tensor(1.0987, device='cuda:0', dtype=torch.float64)
# -30 18 -21
# torch.Size([69, 482, 105]) tensor(1.0935, device='cuda:0', dtype=torch.float64)
# -30 18 -18
# torch.Size([69, 482, 108]) tensor(1.0842, device='cuda:0', dtype=torch.float64)
# -30 18 -15
# torch.Size([69, 482, 111]) tensor(1.0840, device='cuda:0', dtype=torch.float64)
# -30 18 -12
# torch.Size([69, 482, 114]) tensor(1.0777, device='cuda:0', dtype=torch.float64)
# -30 18 -9
# torch.Size([69, 482, 117]) tensor(1.0630, device='cuda:0', dtype=torch.float64)
# -30 18 -6
# torch.Size([69, 482, 120]) tensor(1.0417, device='cuda:0', dtype=torch.float64)
# -30 18 -3
# torch.Size([69, 482, 123]) tensor(1.0268, device='cuda:0', dtype=torch.float64)
# -30 18 0
# torch.Size([69, 482, 126]) tensor(1.0293, device='cuda:0', dtype=torch.float64)
# -30 18 3
# torch.Size([69, 482, 123]) tensor(1.0434, device='cuda:0', dtype=torch.float64)
# -30 18 6
# torch.Size([69, 482, 120]) tensor(1.0625, device='cuda:0', dtype=torch.float64)
# -30 18 9
# torch.Size([69, 482, 117]) tensor(1.0800, device='cuda:0', dtype=torch.float64)
# -30 18 12
# torch.Size([69, 482, 114]) tensor(1.0943, device='cuda:0', dtype=torch.float64)
# -30 18 15
# torch.Size([69, 482, 111]) tensor(1.1017, device='cuda:0', dtype=torch.float64)
# -30 18 18
# torch.Size([69, 482, 108]) tensor(1.1080, device='cuda:0', dtype=torch.float64)
# -30 18 21
# torch.Size([69, 482, 105]) tensor(1.1156, device='cuda:0', dtype=torch.float64)
# -30 18 24
# torch.Size([69, 482, 102]) tensor(1.1262, device='cuda:0', dtype=torch.float64)
# -30 18 27
# torch.Size([69, 482, 99]) tensor(1.1412, device='cuda:0', dtype=torch.float64)
# -30 18 30
# torch.Size([69, 482, 96]) tensor(1.1509, device='cuda:0', dtype=torch.float64)
# -30 21 -30
# torch.Size([72, 482, 96]) tensor(1.0914, device='cuda:0', dtype=torch.float64)
# -30 21 -27
# torch.Size([72, 482, 99]) tensor(1.1001, device='cuda:0', dtype=torch.float64)
# -30 21 -24
# torch.Size([72, 482, 102]) tensor(1.1054, device='cuda:0', dtype=torch.float64)
# -30 21 -21
# torch.Size([72, 482, 105]) tensor(1.1019, device='cuda:0', dtype=torch.float64)
# -30 21 -18
# torch.Size([72, 482, 108]) tensor(1.0920, device='cuda:0', dtype=torch.float64)
# -30 21 -15
# torch.Size([72, 482, 111]) tensor(1.0906, device='cuda:0', dtype=torch.float64)
# -30 21 -12
# torch.Size([72, 482, 114]) tensor(1.0831, device='cuda:0', dtype=torch.float64)
# -30 21 -9
# torch.Size([72, 482, 117]) tensor(1.0691, device='cuda:0', dtype=torch.float64)
# -30 21 -6
# torch.Size([72, 482, 120]) tensor(1.0488, device='cuda:0', dtype=torch.float64)
# -30 21 -3
# torch.Size([72, 482, 123]) tensor(1.0332, device='cuda:0', dtype=torch.float64)
# -30 21 0
# torch.Size([72, 482, 126]) tensor(1.0315, device='cuda:0', dtype=torch.float64)
# -30 21 3
# torch.Size([72, 482, 123]) tensor(1.0446, device='cuda:0', dtype=torch.float64)
# -30 21 6
# torch.Size([72, 482, 120]) tensor(1.0658, device='cuda:0', dtype=torch.float64)
# -30 21 9
# torch.Size([72, 482, 117]) tensor(1.0851, device='cuda:0', dtype=torch.float64)
# -30 21 12
# torch.Size([72, 482, 114]) tensor(1.1008, device='cuda:0', dtype=torch.float64)
# -30 21 15
# torch.Size([72, 482, 111]) tensor(1.1086, device='cuda:0', dtype=torch.float64)
# -30 21 18
# torch.Size([72, 482, 108]) tensor(1.1160, device='cuda:0', dtype=torch.float64)
# -30 21 21
# torch.Size([72, 482, 105]) tensor(1.1241, device='cuda:0', dtype=torch.float64)
# -30 21 24
# torch.Size([72, 482, 102]) tensor(1.1360, device='cuda:0', dtype=torch.float64)
# -30 21 27
# torch.Size([72, 482, 99]) tensor(1.1485, device='cuda:0', dtype=torch.float64)
# -30 21 30
# torch.Size([72, 482, 96]) tensor(1.1582, device='cuda:0', dtype=torch.float64)
# -30 24 -30
# torch.Size([75, 482, 96]) tensor(1.0962, device='cuda:0', dtype=torch.float64)
# -30 24 -27
# torch.Size([75, 482, 99]) tensor(1.1056, device='cuda:0', dtype=torch.float64)
# -30 24 -24
# torch.Size([75, 482, 102]) tensor(1.1121, device='cuda:0', dtype=torch.float64)
# -30 24 -21
# torch.Size([75, 482, 105]) tensor(1.1098, device='cuda:0', dtype=torch.float64)
# -30 24 -18
# torch.Size([75, 482, 108]) tensor(1.1004, device='cuda:0', dtype=torch.float64)
# -30 24 -15
# torch.Size([75, 482, 111]) tensor(1.0964, device='cuda:0', dtype=torch.float64)
# -30 24 -12
# torch.Size([75, 482, 114]) tensor(1.0875, device='cuda:0', dtype=torch.float64)
# -30 24 -9
# torch.Size([75, 482, 117]) tensor(1.0758, device='cuda:0', dtype=torch.float64)
# -30 24 -6
# torch.Size([75, 482, 120]) tensor(1.0600, device='cuda:0', dtype=torch.float64)
# -30 24 -3
# torch.Size([75, 482, 123]) tensor(1.0416, device='cuda:0', dtype=torch.float64)
# -30 24 0
# torch.Size([75, 482, 126]) tensor(1.0347, device='cuda:0', dtype=torch.float64)
# -30 24 3
# torch.Size([75, 482, 123]) tensor(1.0462, device='cuda:0', dtype=torch.float64)
# -30 24 6
# torch.Size([75, 482, 120]) tensor(1.0707, device='cuda:0', dtype=torch.float64)
# -30 24 9
# torch.Size([75, 482, 117]) tensor(1.0918, device='cuda:0', dtype=torch.float64)
# -30 24 12
# torch.Size([75, 482, 114]) tensor(1.1067, device='cuda:0', dtype=torch.float64)
# -30 24 15
# torch.Size([75, 482, 111]) tensor(1.1154, device='cuda:0', dtype=torch.float64)
# -30 24 18
# torch.Size([75, 482, 108]) tensor(1.1230, device='cuda:0', dtype=torch.float64)
# -30 24 21
# torch.Size([75, 482, 105]) tensor(1.1330, device='cuda:0', dtype=torch.float64)
# -30 24 24
# torch.Size([75, 482, 102]) tensor(1.1460, device='cuda:0', dtype=torch.float64)
# -30 24 27
# torch.Size([75, 482, 99]) tensor(1.1573, device='cuda:0', dtype=torch.float64)
# -30 24 30
# torch.Size([75, 482, 96]) tensor(1.1656, device='cuda:0', dtype=torch.float64)
# -30 27 -30
# torch.Size([78, 482, 96]) tensor(1.1028, device='cuda:0', dtype=torch.float64)
# -30 27 -27
# torch.Size([78, 482, 99]) tensor(1.1131, device='cuda:0', dtype=torch.float64)
# -30 27 -24
# torch.Size([78, 482, 102]) tensor(1.1208, device='cuda:0', dtype=torch.float64)
# -30 27 -21
# torch.Size([78, 482, 105]) tensor(1.1206, device='cuda:0', dtype=torch.float64)
# -30 27 -18
# torch.Size([78, 482, 108]) tensor(1.1105, device='cuda:0', dtype=torch.float64)
# -30 27 -15
# torch.Size([78, 482, 111]) tensor(1.1036, device='cuda:0', dtype=torch.float64)
# -30 27 -12
# torch.Size([78, 482, 114]) tensor(1.0945, device='cuda:0', dtype=torch.float64)
# -30 27 -9
# torch.Size([78, 482, 117]) tensor(1.0866, device='cuda:0', dtype=torch.float64)
# -30 27 -6
# torch.Size([78, 482, 120]) tensor(1.0724, device='cuda:0', dtype=torch.float64)
# -30 27 -3
# torch.Size([78, 482, 123]) tensor(1.0532, device='cuda:0', dtype=torch.float64)
# -30 27 0
# torch.Size([78, 482, 126]) tensor(1.0429, device='cuda:0', dtype=torch.float64)
# -30 27 3
# torch.Size([78, 482, 123]) tensor(1.0519, device='cuda:0', dtype=torch.float64)
# -30 27 6
# torch.Size([78, 482, 120]) tensor(1.0776, device='cuda:0', dtype=torch.float64)
# -30 27 9
# torch.Size([78, 482, 117]) tensor(1.0998, device='cuda:0', dtype=torch.float64)
# -30 27 12
# torch.Size([78, 482, 114]) tensor(1.1161, device='cuda:0', dtype=torch.float64)
# -30 27 15
# torch.Size([78, 482, 111]) tensor(1.1247, device='cuda:0', dtype=torch.float64)
# -30 27 18
# torch.Size([78, 482, 108]) tensor(1.1320, device='cuda:0', dtype=torch.float64)
# -30 27 21
# torch.Size([78, 482, 105]) tensor(1.1429, device='cuda:0', dtype=torch.float64)
# -30 27 24
# torch.Size([78, 482, 102]) tensor(1.1574, device='cuda:0', dtype=torch.float64)
# -30 27 27
# torch.Size([78, 482, 99]) tensor(1.1680, device='cuda:0', dtype=torch.float64)
# -30 27 30
# torch.Size([78, 482, 96]) tensor(1.1736, device='cuda:0', dtype=torch.float64)
# -30 30 -30
# torch.Size([81, 482, 96]) tensor(1.1094, device='cuda:0', dtype=torch.float64)
# -30 30 -27
# torch.Size([81, 482, 99]) tensor(1.1202, device='cuda:0', dtype=torch.float64)
# -30 30 -24
# torch.Size([81, 482, 102]) tensor(1.1292, device='cuda:0', dtype=torch.float64)
# -30 30 -21
# torch.Size([81, 482, 105]) tensor(1.1306, device='cuda:0', dtype=torch.float64)
# -30 30 -18
# torch.Size([81, 482, 108]) tensor(1.1209, device='cuda:0', dtype=torch.float64)
# -30 30 -15
# torch.Size([81, 482, 111]) tensor(1.1120, device='cuda:0', dtype=torch.float64)
# -30 30 -12
# torch.Size([81, 482, 114]) tensor(1.1041, device='cuda:0', dtype=torch.float64)
# -30 30 -9
# torch.Size([81, 482, 117]) tensor(1.0984, device='cuda:0', dtype=torch.float64)
# -30 30 -6
# torch.Size([81, 482, 120]) tensor(1.0850, device='cuda:0', dtype=torch.float64)
# -30 30 -3
# torch.Size([81, 482, 123]) tensor(1.0642, device='cuda:0', dtype=torch.float64)
# -30 30 0
# torch.Size([81, 482, 126]) tensor(1.0513, device='cuda:0', dtype=torch.float64)
# -30 30 3
# torch.Size([81, 482, 123]) tensor(1.0593, device='cuda:0', dtype=torch.float64)
# -30 30 6
# torch.Size([81, 482, 120]) tensor(1.0851, device='cuda:0', dtype=torch.float64)
# -30 30 9
# torch.Size([81, 482, 117]) tensor(1.1081, device='cuda:0', dtype=torch.float64)
# -30 30 12
# torch.Size([81, 482, 114]) tensor(1.1258, device='cuda:0', dtype=torch.float64)
# -30 30 15
# torch.Size([81, 482, 111]) tensor(1.1342, device='cuda:0', dtype=torch.float64)
# -30 30 18
# torch.Size([81, 482, 108]) tensor(1.1417, device='cuda:0', dtype=torch.float64)
# -30 30 21
# torch.Size([81, 482, 105]) tensor(1.1532, device='cuda:0', dtype=torch.float64)
# -30 30 24
# torch.Size([81, 482, 102]) tensor(1.1685, device='cuda:0', dtype=torch.float64)
# -30 30 27
# torch.Size([81, 482, 99]) tensor(1.1778, device='cuda:0', dtype=torch.float64)
# -30 30 30
# torch.Size([81, 482, 96]) tensor(1.1824, device='cuda:0', dtype=torch.float64)
# -27 -30 -30
# torch.Size([21, 485, 96]) tensor(1.1916, device='cuda:0', dtype=torch.float64)
# -27 -30 -27
# torch.Size([21, 485, 99]) tensor(1.2295, device='cuda:0', dtype=torch.float64)
# -27 -30 -24
# torch.Size([21, 485, 102]) tensor(1.2258, device='cuda:0', dtype=torch.float64)
# -27 -30 -21
# torch.Size([21, 485, 105]) tensor(1.2053, device='cuda:0', dtype=torch.float64)
# -27 -30 -18
# torch.Size([21, 485, 108]) tensor(1.1942, device='cuda:0', dtype=torch.float64)
# -27 -30 -15
# torch.Size([21, 485, 111]) tensor(1.1830, device='cuda:0', dtype=torch.float64)
# -27 -30 -12
# torch.Size([21, 485, 114]) tensor(1.1770, device='cuda:0', dtype=torch.float64)
# -27 -30 -9
# torch.Size([21, 485, 117]) tensor(1.1737, device='cuda:0', dtype=torch.float64)
# -27 -30 -6
# torch.Size([21, 485, 120]) tensor(1.1566, device='cuda:0', dtype=torch.float64)
# -27 -30 -3
# torch.Size([21, 485, 123]) tensor(1.1511, device='cuda:0', dtype=torch.float64)
# -27 -30 0
# torch.Size([21, 485, 126]) tensor(1.1475, device='cuda:0', dtype=torch.float64)
# -27 -30 3
# torch.Size([21, 485, 123]) tensor(1.1487, device='cuda:0', dtype=torch.float64)
# -27 -30 6
# torch.Size([21, 485, 120]) tensor(1.1486, device='cuda:0', dtype=torch.float64)
# -27 -30 9
# torch.Size([21, 485, 117]) tensor(1.1513, device='cuda:0', dtype=torch.float64)
# -27 -30 12
# torch.Size([21, 485, 114]) tensor(1.1622, device='cuda:0', dtype=torch.float64)
# -27 -30 15
# torch.Size([21, 485, 111]) tensor(1.1665, device='cuda:0', dtype=torch.float64)
# -27 -30 18
# torch.Size([21, 485, 108]) tensor(1.1599, device='cuda:0', dtype=torch.float64)
# -27 -30 21
# torch.Size([21, 485, 105]) tensor(1.1770, device='cuda:0', dtype=torch.float64)
# -27 -30 24
# torch.Size([21, 485, 102]) tensor(1.1906, device='cuda:0', dtype=torch.float64)
# -27 -30 27
# torch.Size([21, 485, 99]) tensor(1.2061, device='cuda:0', dtype=torch.float64)
# -27 -30 30
# torch.Size([21, 485, 96]) tensor(1.2260, device='cuda:0', dtype=torch.float64)
# -27 -27 -30
# torch.Size([24, 485, 96]) tensor(1.1756, device='cuda:0', dtype=torch.float64)
# -27 -27 -27
# torch.Size([24, 485, 99]) tensor(1.2143, device='cuda:0', dtype=torch.float64)
# -27 -27 -24
# torch.Size([24, 485, 102]) tensor(1.2126, device='cuda:0', dtype=torch.float64)
# -27 -27 -21
# torch.Size([24, 485, 105]) tensor(1.1945, device='cuda:0', dtype=torch.float64)
# -27 -27 -18
# torch.Size([24, 485, 108]) tensor(1.1838, device='cuda:0', dtype=torch.float64)
# -27 -27 -15
# torch.Size([24, 485, 111]) tensor(1.1742, device='cuda:0', dtype=torch.float64)
# -27 -27 -12
# torch.Size([24, 485, 114]) tensor(1.1676, device='cuda:0', dtype=torch.float64)
# -27 -27 -9
# torch.Size([24, 485, 117]) tensor(1.1649, device='cuda:0', dtype=torch.float64)
# -27 -27 -6
# torch.Size([24, 485, 120]) tensor(1.1509, device='cuda:0', dtype=torch.float64)
# -27 -27 -3
# torch.Size([24, 485, 123]) tensor(1.1454, device='cuda:0', dtype=torch.float64)
# -27 -27 0
# torch.Size([24, 485, 126]) tensor(1.1384, device='cuda:0', dtype=torch.float64)
# -27 -27 3
# torch.Size([24, 485, 123]) tensor(1.1368, device='cuda:0', dtype=torch.float64)
# -27 -27 6
# torch.Size([24, 485, 120]) tensor(1.1398, device='cuda:0', dtype=torch.float64)
# -27 -27 9
# torch.Size([24, 485, 117]) tensor(1.1461, device='cuda:0', dtype=torch.float64)
# -27 -27 12
# torch.Size([24, 485, 114]) tensor(1.1579, device='cuda:0', dtype=torch.float64)
# -27 -27 15
# torch.Size([24, 485, 111]) tensor(1.1623, device='cuda:0', dtype=torch.float64)
# -27 -27 18
# torch.Size([24, 485, 108]) tensor(1.1561, device='cuda:0', dtype=torch.float64)
# -27 -27 21
# torch.Size([24, 485, 105]) tensor(1.1705, device='cuda:0', dtype=torch.float64)
# -27 -27 24
# torch.Size([24, 485, 102]) tensor(1.1863, device='cuda:0', dtype=torch.float64)
# -27 -27 27
# torch.Size([24, 485, 99]) tensor(1.2011, device='cuda:0', dtype=torch.float64)
# -27 -27 30
# torch.Size([24, 485, 96]) tensor(1.2212, device='cuda:0', dtype=torch.float64)
# -27 -24 -30
# torch.Size([27, 485, 96]) tensor(1.1563, device='cuda:0', dtype=torch.float64)
# -27 -24 -27
# torch.Size([27, 485, 99]) tensor(1.1938, device='cuda:0', dtype=torch.float64)
# -27 -24 -24
# torch.Size([27, 485, 102]) tensor(1.1934, device='cuda:0', dtype=torch.float64)
# -27 -24 -21
# torch.Size([27, 485, 105]) tensor(1.1765, device='cuda:0', dtype=torch.float64)
# -27 -24 -18
# torch.Size([27, 485, 108]) tensor(1.1686, device='cuda:0', dtype=torch.float64)
# -27 -24 -15
# torch.Size([27, 485, 111]) tensor(1.1624, device='cuda:0', dtype=torch.float64)
# -27 -24 -12
# torch.Size([27, 485, 114]) tensor(1.1545, device='cuda:0', dtype=torch.float64)
# -27 -24 -9
# torch.Size([27, 485, 117]) tensor(1.1521, device='cuda:0', dtype=torch.float64)
# -27 -24 -6
# torch.Size([27, 485, 120]) tensor(1.1398, device='cuda:0', dtype=torch.float64)
# -27 -24 -3
# torch.Size([27, 485, 123]) tensor(1.1338, device='cuda:0', dtype=torch.float64)
# -27 -24 0
# torch.Size([27, 485, 126]) tensor(1.1259, device='cuda:0', dtype=torch.float64)
# -27 -24 3
# torch.Size([27, 485, 123]) tensor(1.1239, device='cuda:0', dtype=torch.float64)
# -27 -24 6
# torch.Size([27, 485, 120]) tensor(1.1288, device='cuda:0', dtype=torch.float64)
# -27 -24 9
# torch.Size([27, 485, 117]) tensor(1.1355, device='cuda:0', dtype=torch.float64)
# -27 -24 12
# torch.Size([27, 485, 114]) tensor(1.1449, device='cuda:0', dtype=torch.float64)
# -27 -24 15
# torch.Size([27, 485, 111]) tensor(1.1495, device='cuda:0', dtype=torch.float64)
# -27 -24 18
# torch.Size([27, 485, 108]) tensor(1.1440, device='cuda:0', dtype=torch.float64)
# -27 -24 21
# torch.Size([27, 485, 105]) tensor(1.1556, device='cuda:0', dtype=torch.float64)
# -27 -24 24
# torch.Size([27, 485, 102]) tensor(1.1720, device='cuda:0', dtype=torch.float64)
# -27 -24 27
# torch.Size([27, 485, 99]) tensor(1.1890, device='cuda:0', dtype=torch.float64)
# -27 -24 30
# torch.Size([27, 485, 96]) tensor(1.2095, device='cuda:0', dtype=torch.float64)
# -27 -21 -30
# torch.Size([30, 485, 96]) tensor(1.1343, device='cuda:0', dtype=torch.float64)
# -27 -21 -27
# torch.Size([30, 485, 99]) tensor(1.1713, device='cuda:0', dtype=torch.float64)
# -27 -21 -24
# torch.Size([30, 485, 102]) tensor(1.1727, device='cuda:0', dtype=torch.float64)
# -27 -21 -21
# torch.Size([30, 485, 105]) tensor(1.1556, device='cuda:0', dtype=torch.float64)
# -27 -21 -18
# torch.Size([30, 485, 108]) tensor(1.1488, device='cuda:0', dtype=torch.float64)
# -27 -21 -15
# torch.Size([30, 485, 111]) tensor(1.1446, device='cuda:0', dtype=torch.float64)
# -27 -21 -12
# torch.Size([30, 485, 114]) tensor(1.1386, device='cuda:0', dtype=torch.float64)
# -27 -21 -9
# torch.Size([30, 485, 117]) tensor(1.1337, device='cuda:0', dtype=torch.float64)
# -27 -21 -6
# torch.Size([30, 485, 120]) tensor(1.1217, device='cuda:0', dtype=torch.float64)
# -27 -21 -3
# torch.Size([30, 485, 123]) tensor(1.1151, device='cuda:0', dtype=torch.float64)
# -27 -21 0
# torch.Size([30, 485, 126]) tensor(1.1069, device='cuda:0', dtype=torch.float64)
# -27 -21 3
# torch.Size([30, 485, 123]) tensor(1.1081, device='cuda:0', dtype=torch.float64)
# -27 -21 6
# torch.Size([30, 485, 120]) tensor(1.1149, device='cuda:0', dtype=torch.float64)
# -27 -21 9
# torch.Size([30, 485, 117]) tensor(1.1196, device='cuda:0', dtype=torch.float64)
# -27 -21 12
# torch.Size([30, 485, 114]) tensor(1.1298, device='cuda:0', dtype=torch.float64)
# -27 -21 15
# torch.Size([30, 485, 111]) tensor(1.1326, device='cuda:0', dtype=torch.float64)
# -27 -21 18
# torch.Size([30, 485, 108]) tensor(1.1275, device='cuda:0', dtype=torch.float64)
# -27 -21 21
# torch.Size([30, 485, 105]) tensor(1.1388, device='cuda:0', dtype=torch.float64)
# -27 -21 24
# torch.Size([30, 485, 102]) tensor(1.1544, device='cuda:0', dtype=torch.float64)
# -27 -21 27
# torch.Size([30, 485, 99]) tensor(1.1745, device='cuda:0', dtype=torch.float64)
# -27 -21 30
# torch.Size([30, 485, 96]) tensor(1.1933, device='cuda:0', dtype=torch.float64)
# -27 -18 -30
# torch.Size([33, 485, 96]) tensor(1.1139, device='cuda:0', dtype=torch.float64)
# -27 -18 -27
# torch.Size([33, 485, 99]) tensor(1.1488, device='cuda:0', dtype=torch.float64)
# -27 -18 -24
# torch.Size([33, 485, 102]) tensor(1.1518, device='cuda:0', dtype=torch.float64)
# -27 -18 -21
# torch.Size([33, 485, 105]) tensor(1.1358, device='cuda:0', dtype=torch.float64)
# -27 -18 -18
# torch.Size([33, 485, 108]) tensor(1.1283, device='cuda:0', dtype=torch.float64)
# -27 -18 -15
# torch.Size([33, 485, 111]) tensor(1.1266, device='cuda:0', dtype=torch.float64)
# -27 -18 -12
# ...
# 1 1 -1
# torch.Size([52, 511, 125]) tensor(0.5172, device='cuda:0', dtype=torch.float64)
# 1 1 0
# torch.Size([52, 511, 126]) tensor(0.4875, device='cuda:0', dtype=torch.float64)
# 1 1 1
# torch.Size([52, 511, 125]) tensor(0.5090, device='cuda:0', dtype=torch.float64)
# 1 1 2
# torch.Size([52, 511, 124]) tensor(0.5789, device='cuda:0', dtype=torch.float64)
# 1 1 3
# torch.Size([52, 511, 123]) tensor(0.6689, device='cuda:0', dtype=torch.float64)
# 1 1 4
# torch.Size([52, 511, 122]) tensor(0.7585, device='cuda:0', dtype=torch.float64)
# 1 1 5
# torch.Size([52, 511, 121]) tensor(0.8366, device='cuda:0', dtype=torch.float64)
# 1 2 -5
# torch.Size([53, 511, 121]) tensor(0.8399, device='cuda:0', dtype=torch.float64)
# 1 2 -4
# torch.Size([53, 511, 122]) tensor(0.7677, device='cuda:0', dtype=torch.float64)
# 1 2 -3
# torch.Size([53, 511, 123]) tensor(0.6815, device='cuda:0', dtype=torch.float64)
# 1 2 -2
# torch.Size([53, 511, 124]) tensor(0.5893, device='cuda:0', dtype=torch.float64)
# 1 2 -1
# torch.Size([53, 511, 125]) tensor(0.5151, device='cuda:0', dtype=torch.float64)
# 1 2 0
# torch.Size([53, 511, 126]) tensor(0.4907, device='cuda:0', dtype=torch.float64)
# 1 2 1
# torch.Size([53, 511, 125]) tensor(0.5189, device='cuda:0', dtype=torch.float64)
# 1 2 2
# torch.Size([53, 511, 124]) tensor(0.5891, device='cuda:0', dtype=torch.float64)
# 1 2 3
# torch.Size([53, 511, 123]) tensor(0.6761, device='cuda:0', dtype=torch.float64)
# 1 2 4
# torch.Size([53, 511, 122]) tensor(0.7633, device='cuda:0', dtype=torch.float64)
# 1 2 5
# torch.Size([53, 511, 121]) tensor(0.8397, device='cuda:0', dtype=torch.float64)
# 1 3 -5
# torch.Size([54, 511, 121]) tensor(0.8404, device='cuda:0', dtype=torch.float64)
# 1 3 -4
# torch.Size([54, 511, 122]) tensor(0.7684, device='cuda:0', dtype=torch.float64)
# 1 3 -3
# torch.Size([54, 511, 123]) tensor(0.6826, device='cuda:0', dtype=torch.float64)
# 1 3 -2
# torch.Size([54, 511, 124]) tensor(0.5921, device='cuda:0', dtype=torch.float64)
# 1 3 -1
# torch.Size([54, 511, 125]) tensor(0.5223, device='cuda:0', dtype=torch.float64)
# 1 3 0
# torch.Size([54, 511, 126]) tensor(0.5053, device='cuda:0', dtype=torch.float64)
# 1 3 1
# torch.Size([54, 511, 125]) tensor(0.5373, device='cuda:0', dtype=torch.float64)
# 1 3 2
# torch.Size([54, 511, 124]) tensor(0.6036, device='cuda:0', dtype=torch.float64)
# 1 3 3
# torch.Size([54, 511, 123]) tensor(0.6855, device='cuda:0', dtype=torch.float64)
# 1 3 4
# torch.Size([54, 511, 122]) tensor(0.7693, device='cuda:0', dtype=torch.float64)
# 1 3 5
# torch.Size([54, 511, 121]) tensor(0.8428, device='cuda:0', dtype=torch.float64)
# 1 4 -5
# torch.Size([55, 511, 121]) tensor(0.8419, device='cuda:0', dtype=torch.float64)
# 1 4 -4
# torch.Size([55, 511, 122]) tensor(0.7707, device='cuda:0', dtype=torch.float64)
# 1 4 -3
# torch.Size([55, 511, 123]) tensor(0.6868, device='cuda:0', dtype=torch.float64)
# 1 4 -2
# torch.Size([55, 511, 124]) tensor(0.6009, device='cuda:0', dtype=torch.float64)
# 1 4 -1
# torch.Size([55, 511, 125]) tensor(0.5386, device='cuda:0', dtype=torch.float64)
# 1 4 0
# torch.Size([55, 511, 126]) tensor(0.5278, device='cuda:0', dtype=torch.float64)
# 1 4 1
# torch.Size([55, 511, 125]) tensor(0.5593, device='cuda:0', dtype=torch.float64)
# 1 4 2
# torch.Size([55, 511, 124]) tensor(0.6199, device='cuda:0', dtype=torch.float64)
# 1 4 3
# torch.Size([55, 511, 123]) tensor(0.6963, device='cuda:0', dtype=torch.float64)
# 1 4 4
# torch.Size([55, 511, 122]) tensor(0.7756, device='cuda:0', dtype=torch.float64)
# 1 4 5
# torch.Size([55, 511, 121]) tensor(0.8462, device='cuda:0', dtype=torch.float64)
# 1 5 -5
# torch.Size([56, 511, 121]) tensor(0.8443, device='cuda:0', dtype=torch.float64)
# 1 5 -4
# torch.Size([56, 511, 122]) tensor(0.7747, device='cuda:0', dtype=torch.float64)
# 1 5 -3
# torch.Size([56, 511, 123]) tensor(0.6947, device='cuda:0', dtype=torch.float64)
# 1 5 -2
# torch.Size([56, 511, 124]) tensor(0.6156, device='cuda:0', dtype=torch.float64)
# 1 5 -1
# torch.Size([56, 511, 125]) tensor(0.5613, device='cuda:0', dtype=torch.float64)
# 1 5 0
# torch.Size([56, 511, 126]) tensor(0.5536, device='cuda:0', dtype=torch.float64)
# 1 5 1
# torch.Size([56, 511, 125]) tensor(0.5818, device='cuda:0', dtype=torch.float64)
# 1 5 2
# torch.Size([56, 511, 124]) tensor(0.6369, device='cuda:0', dtype=torch.float64)
# 1 5 3
# torch.Size([56, 511, 123]) tensor(0.7075, device='cuda:0', dtype=torch.float64)
# 1 5 4
# torch.Size([56, 511, 122]) tensor(0.7823, device='cuda:0', dtype=torch.float64)
# 1 5 5
# torch.Size([56, 511, 121]) tensor(0.8501, device='cuda:0', dtype=torch.float64)
# 1 6 -5
# torch.Size([57, 511, 121]) tensor(0.8477, device='cuda:0', dtype=torch.float64)
# 1 6 -4
# torch.Size([57, 511, 122]) tensor(0.7807, device='cuda:0', dtype=torch.float64)
# 1 6 -3
# torch.Size([57, 511, 123]) tensor(0.7058, device='cuda:0', dtype=torch.float64)
# 1 6 -2
# torch.Size([57, 511, 124]) tensor(0.6342, device='cuda:0', dtype=torch.float64)
# 1 6 -1
# torch.Size([57, 511, 125]) tensor(0.5867, device='cuda:0', dtype=torch.float64)
# 1 6 0
# torch.Size([57, 511, 126]) tensor(0.5791, device='cuda:0', dtype=torch.float64)
# 1 6 1
# torch.Size([57, 511, 125]) tensor(0.6035, device='cuda:0', dtype=torch.float64)
# 1 6 2
# torch.Size([57, 511, 124]) tensor(0.6533, device='cuda:0', dtype=torch.float64)
# 1 6 3
# torch.Size([57, 511, 123]) tensor(0.7185, device='cuda:0', dtype=torch.float64)
# 1 6 4
# torch.Size([57, 511, 122]) tensor(0.7892, device='cuda:0', dtype=torch.float64)
# 1 6 5
# torch.Size([57, 511, 121]) tensor(0.8541, device='cuda:0', dtype=torch.float64)
# 2 -4 -5
# torch.Size([47, 510, 121]) tensor(0.8593, device='cuda:0', dtype=torch.float64)
# 2 -4 -4
# torch.Size([47, 510, 122]) tensor(0.8002, device='cuda:0', dtype=torch.float64)
# 2 -4 -3
# torch.Size([47, 510, 123]) tensor(0.7327, device='cuda:0', dtype=torch.float64)
# 2 -4 -2
# torch.Size([47, 510, 124]) tensor(0.6657, device='cuda:0', dtype=torch.float64)
# 2 -4 -1
# torch.Size([47, 510, 125]) tensor(0.6174, device='cuda:0', dtype=torch.float64)
# 2 -4 0
# torch.Size([47, 510, 126]) tensor(0.6031, device='cuda:0', dtype=torch.float64)
# 2 -4 1
# torch.Size([47, 510, 125]) tensor(0.6158, device='cuda:0', dtype=torch.float64)
# 2 -4 2
# torch.Size([47, 510, 124]) tensor(0.6581, device='cuda:0', dtype=torch.float64)
# 2 -4 3
# torch.Size([47, 510, 123]) tensor(0.7196, device='cuda:0', dtype=torch.float64)
# 2 -4 4
# torch.Size([47, 510, 122]) tensor(0.7887, device='cuda:0', dtype=torch.float64)
# 2 -4 5
# torch.Size([47, 510, 121]) tensor(0.8536, device='cuda:0', dtype=torch.float64)
# 2 -3 -5
# torch.Size([48, 510, 121]) tensor(0.8581, device='cuda:0', dtype=torch.float64)
# 2 -3 -4
# torch.Size([48, 510, 122]) tensor(0.7978, device='cuda:0', dtype=torch.float64)
# 2 -3 -3
# torch.Size([48, 510, 123]) tensor(0.7283, device='cuda:0', dtype=torch.float64)
# 2 -3 -2
# torch.Size([48, 510, 124]) tensor(0.6587, device='cuda:0', dtype=torch.float64)
# 2 -3 -1
# torch.Size([48, 510, 125]) tensor(0.6070, device='cuda:0', dtype=torch.float64)
# 2 -3 0
# torch.Size([48, 510, 126]) tensor(0.5887, device='cuda:0', dtype=torch.float64)
# 2 -3 1
# torch.Size([48, 510, 125]) tensor(0.5997, device='cuda:0', dtype=torch.float64)
# 2 -3 2
# torch.Size([48, 510, 124]) tensor(0.6436, device='cuda:0', dtype=torch.float64)
# 2 -3 3
# torch.Size([48, 510, 123]) tensor(0.7088, device='cuda:0', dtype=torch.float64)
# 2 -3 4
# torch.Size([48, 510, 122]) tensor(0.7817, device='cuda:0', dtype=torch.float64)
# 2 -3 5
# torch.Size([48, 510, 121]) tensor(0.8492, device='cuda:0', dtype=torch.float64)
# 2 -2 -5
# torch.Size([49, 510, 121]) tensor(0.8569, device='cuda:0', dtype=torch.float64)
# 2 -2 -4
# torch.Size([49, 510, 122]) tensor(0.7951, device='cuda:0', dtype=torch.float64)
# 2 -2 -3
# torch.Size([49, 510, 123]) tensor(0.7236, device='cuda:0', dtype=torch.float64)
# 2 -2 -2
# torch.Size([49, 510, 124]) tensor(0.6514, device='cuda:0', dtype=torch.float64)
# 2 -2 -1
# torch.Size([49, 510, 125]) tensor(0.5964, device='cuda:0', dtype=torch.float64)
# 2 -2 0
# torch.Size([49, 510, 126]) tensor(0.5745, device='cuda:0', dtype=torch.float64)
# 2 -2 1
# torch.Size([49, 510, 125]) tensor(0.5847, device='cuda:0', dtype=torch.float64)
# 2 -2 2
# torch.Size([49, 510, 124]) tensor(0.6309, device='cuda:0', dtype=torch.float64)
# 2 -2 3
# torch.Size([49, 510, 123]) tensor(0.7005, device='cuda:0', dtype=torch.float64)
# 2 -2 4
# torch.Size([49, 510, 122]) tensor(0.7768, device='cuda:0', dtype=torch.float64)
# 2 -2 5
# torch.Size([49, 510, 121]) tensor(0.8463, device='cuda:0', dtype=torch.float64)
# 2 -1 -5
# torch.Size([50, 510, 121]) tensor(0.8555, device='cuda:0', dtype=torch.float64)
# 2 -1 -4
# torch.Size([50, 510, 122]) tensor(0.7926, device='cuda:0', dtype=torch.float64)
# 2 -1 -3
# torch.Size([50, 510, 123]) tensor(0.7194, device='cuda:0', dtype=torch.float64)
# 2 -1 -2
# torch.Size([50, 510, 124]) tensor(0.6447, device='cuda:0', dtype=torch.float64)
# 2 -1 -1
# torch.Size([50, 510, 125]) tensor(0.5863, device='cuda:0', dtype=torch.float64)
# 2 -1 0
# torch.Size([50, 510, 126]) tensor(0.5617, device='cuda:0', dtype=torch.float64)
# 2 -1 1
# torch.Size([50, 510, 125]) tensor(0.5722, device='cuda:0', dtype=torch.float64)
# 2 -1 2
# torch.Size([50, 510, 124]) tensor(0.6217, device='cuda:0', dtype=torch.float64)
# 2 -1 3
# torch.Size([50, 510, 123]) tensor(0.6952, device='cuda:0', dtype=torch.float64)
# 2 -1 4
# torch.Size([50, 510, 122]) tensor(0.7739, device='cuda:0', dtype=torch.float64)
# 2 -1 5
# torch.Size([50, 510, 121]) tensor(0.8449, device='cuda:0', dtype=torch.float64)
# 2 0 -5
# torch.Size([51, 510, 121]) tensor(0.8544, device='cuda:0', dtype=torch.float64)
# 2 0 -4
# torch.Size([51, 510, 122]) tensor(0.7905, device='cuda:0', dtype=torch.float64)
# 2 0 -3
# torch.Size([51, 510, 123]) tensor(0.7163, device='cuda:0', dtype=torch.float64)
# 2 0 -2
# torch.Size([51, 510, 124]) tensor(0.6391, device='cuda:0', dtype=torch.float64)
# 2 0 -1
# torch.Size([51, 510, 125]) tensor(0.5777, device='cuda:0', dtype=torch.float64)
# 2 0 0
# torch.Size([51, 510, 126]) tensor(0.5515, device='cuda:0', dtype=torch.float64)
# 2 0 1
# torch.Size([51, 510, 125]) tensor(0.5641, device='cuda:0', dtype=torch.float64)
# 2 0 2
# torch.Size([51, 510, 124]) tensor(0.6174, device='cuda:0', dtype=torch.float64)
# 2 0 3
# torch.Size([51, 510, 123]) tensor(0.6935, device='cuda:0', dtype=torch.float64)
# 2 0 4
# torch.Size([51, 510, 122]) tensor(0.7733, device='cuda:0', dtype=torch.float64)
# 2 0 5
# torch.Size([51, 510, 121]) tensor(0.8452, device='cuda:0', dtype=torch.float64)
# 2 1 -5
# torch.Size([52, 510, 121]) tensor(0.8539, device='cuda:0', dtype=torch.float64)
# 2 1 -4
# torch.Size([52, 510, 122]) tensor(0.7894, device='cuda:0', dtype=torch.float64)
# 2 1 -3
# torch.Size([52, 510, 123]) tensor(0.7142, device='cuda:0', dtype=torch.float64)
# 2 1 -2
# torch.Size([52, 510, 124]) tensor(0.6352, device='cuda:0', dtype=torch.float64)
# 2 1 -1
# torch.Size([52, 510, 125]) tensor(0.5715, device='cuda:0', dtype=torch.float64)
# 2 1 0
# torch.Size([52, 510, 126]) tensor(0.5457, device='cuda:0', dtype=torch.float64)
# 2 1 1
# torch.Size([52, 510, 125]) tensor(0.5625, device='cuda:0', dtype=torch.float64)
# 2 1 2
# torch.Size([52, 510, 124]) tensor(0.6194, device='cuda:0', dtype=torch.float64)
# 2 1 3
# torch.Size([52, 510, 123]) tensor(0.6964, device='cuda:0', dtype=torch.float64)
# 2 1 4
# torch.Size([52, 510, 122]) tensor(0.7757, device='cuda:0', dtype=torch.float64)
# 2 1 5
# torch.Size([52, 510, 121]) tensor(0.8474, device='cuda:0', dtype=torch.float64)
# 2 2 -5
# torch.Size([53, 510, 121]) tensor(0.8536, device='cuda:0', dtype=torch.float64)
# 2 2 -4
# torch.Size([53, 510, 122]) tensor(0.7890, device='cuda:0', dtype=torch.float64)
# 2 2 -3
# torch.Size([53, 510, 123]) tensor(0.7132, device='cuda:0', dtype=torch.float64)
# 2 2 -2
# torch.Size([53, 510, 124]) tensor(0.6336, device='cuda:0', dtype=torch.float64)
# 2 2 -1
# torch.Size([53, 510, 125]) tensor(0.5694, device='cuda:0', dtype=torch.float64)
# 2 2 0
# torch.Size([53, 510, 126]) tensor(0.5467, device='cuda:0', dtype=torch.float64)
# 2 2 1
# torch.Size([53, 510, 125]) tensor(0.5687, device='cuda:0', dtype=torch.float64)
# 2 2 2
# torch.Size([53, 510, 124]) tensor(0.6274, device='cuda:0', dtype=torch.float64)
# 2 2 3
# torch.Size([53, 510, 123]) tensor(0.7026, device='cuda:0', dtype=torch.float64)
# 2 2 4
# torch.Size([53, 510, 122]) tensor(0.7803, device='cuda:0', dtype=torch.float64)
# 2 2 5
# torch.Size([53, 510, 121]) tensor(0.8507, device='cuda:0', dtype=torch.float64)
# 2 3 -5
# torch.Size([54, 510, 121]) tensor(0.8541, device='cuda:0', dtype=torch.float64)
# 2 3 -4
# torch.Size([54, 510, 122]) tensor(0.7896, device='cuda:0', dtype=torch.float64)
# 2 3 -3
# torch.Size([54, 510, 123]) tensor(0.7139, device='cuda:0', dtype=torch.float64)
# 2 3 -2
# torch.Size([54, 510, 124]) tensor(0.6352, device='cuda:0', dtype=torch.float64)
# 2 3 -1
# torch.Size([54, 510, 125]) tensor(0.5737, device='cuda:0', dtype=torch.float64)
# 2 3 0
# torch.Size([54, 510, 126]) tensor(0.5561, device='cuda:0', dtype=torch.float64)
# 2 3 1
# torch.Size([54, 510, 125]) tensor(0.5820, device='cuda:0', dtype=torch.float64)
# 2 3 2
# torch.Size([54, 510, 124]) tensor(0.6392, device='cuda:0', dtype=torch.float64)
# 2 3 3
# torch.Size([54, 510, 123]) tensor(0.7111, device='cuda:0', dtype=torch.float64)
# 2 3 4
# torch.Size([54, 510, 122]) tensor(0.7863, device='cuda:0', dtype=torch.float64)
# 2 3 5
# torch.Size([54, 510, 121]) tensor(0.8540, device='cuda:0', dtype=torch.float64)
# 2 4 -5
# torch.Size([55, 510, 121]) tensor(0.8555, device='cuda:0', dtype=torch.float64)
# 2 4 -4
# torch.Size([55, 510, 122]) tensor(0.7914, device='cuda:0', dtype=torch.float64)
# 2 4 -3
# torch.Size([55, 510, 123]) tensor(0.7171, device='cuda:0', dtype=torch.float64)
# 2 4 -2
# torch.Size([55, 510, 124]) tensor(0.6411, device='cuda:0', dtype=torch.float64)
# 2 4 -1
# torch.Size([55, 510, 125]) tensor(0.5847, device='cuda:0', dtype=torch.float64)
# 2 4 0
# torch.Size([55, 510, 126]) tensor(0.5725, device='cuda:0', dtype=torch.float64)
# 2 4 1
# torch.Size([55, 510, 125]) tensor(0.5999, device='cuda:0', dtype=torch.float64)
# 2 4 2
# torch.Size([55, 510, 124]) tensor(0.6536, device='cuda:0', dtype=torch.float64)
# 2 4 3
# torch.Size([55, 510, 123]) tensor(0.7213, device='cuda:0', dtype=torch.float64)
# 2 4 4
# torch.Size([55, 510, 122]) tensor(0.7928, device='cuda:0', dtype=torch.float64)
# 2 4 5
# torch.Size([55, 510, 121]) tensor(0.8576, device='cuda:0', dtype=torch.float64)
# 2 5 -5
# torch.Size([56, 510, 121]) tensor(0.8575, device='cuda:0', dtype=torch.float64)
# 2 5 -4
# torch.Size([56, 510, 122]) tensor(0.7944, device='cuda:0', dtype=torch.float64)
# 2 5 -3
# torch.Size([56, 510, 123]) tensor(0.7227, device='cuda:0', dtype=torch.float64)
# 2 5 -2
# torch.Size([56, 510, 124]) tensor(0.6514, device='cuda:0', dtype=torch.float64)
# 2 5 -1
# torch.Size([56, 510, 125]) tensor(0.6013, device='cuda:0', dtype=torch.float64)
# 2 5 0
# torch.Size([56, 510, 126]) tensor(0.5933, device='cuda:0', dtype=torch.float64)
# 2 5 1
# torch.Size([56, 510, 125]) tensor(0.6195, device='cuda:0', dtype=torch.float64)
# 2 5 2
# torch.Size([56, 510, 124]) tensor(0.6693, device='cuda:0', dtype=torch.float64)
# 2 5 3
# torch.Size([56, 510, 123]) tensor(0.7324, device='cuda:0', dtype=torch.float64)
# 2 5 4
# torch.Size([56, 510, 122]) tensor(0.7998, device='cuda:0', dtype=torch.float64)
# 2 5 5
# torch.Size([56, 510, 121]) tensor(0.8618, device='cuda:0', dtype=torch.float64)
# 2 6 -5
# torch.Size([57, 510, 121]) tensor(0.8602, device='cuda:0', dtype=torch.float64)
# 2 6 -4
# torch.Size([57, 510, 122]) tensor(0.7990, device='cuda:0', dtype=torch.float64)
# 2 6 -3
# torch.Size([57, 510, 123]) tensor(0.7310, device='cuda:0', dtype=torch.float64)
# 2 6 -2
# torch.Size([57, 510, 124]) tensor(0.6655, device='cuda:0', dtype=torch.float64)
# 2 6 -1
# torch.Size([57, 510, 125]) tensor(0.6219, device='cuda:0', dtype=torch.float64)
# 2 6 0
# torch.Size([57, 510, 126]) tensor(0.6155, device='cuda:0', dtype=torch.float64)
# 2 6 1
# torch.Size([57, 510, 125]) tensor(0.6392, device='cuda:0', dtype=torch.float64)
# 2 6 2
# torch.Size([57, 510, 124]) tensor(0.6850, device='cuda:0', dtype=torch.float64)
# 2 6 3
# torch.Size([57, 510, 123]) tensor(0.7433, device='cuda:0', dtype=torch.float64)
# 2 6 4
# torch.Size([57, 510, 122]) tensor(0.8068, device='cuda:0', dtype=torch.float64)
# 2 6 5
# torch.Size([57, 510, 121]) tensor(0.8660, device='cuda:0', dtype=torch.float64)
# -3 1 0 tensor(0.2348, device='cuda:0', dtype=torch.float64)
# totally 265.321791

# %%
img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
img1=import_img(img_path,0,dim_elem_num)
img2=import_img(img_path,1,dim_elem_num)
print(loss_fun(img1,img2,[30,30,30],alpha=10e-6)-loss_fun(img1,img2,[30,30,30],alpha=0))
# Out:
# (512, 512, 126) 1.9703597381211002
# (512, 512, 126) 1.9433597381211003
# 0.026999999999999913

# %%
img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
i,j=836,865
img1=import_img(img_path,i,dim_elem_num)
img2=import_img(img_path,j,dim_elem_num)
border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
print(border)
#border=get_2img_border_after_shift(dim_elem_num,border1,[2,40,0])
a1=img1[border[0,2]:border[0,3],border[0,0]:border[0,1],50]
a2=img2[border[1,2]:border[1,3],border[1,0]:border[1,1],50]
print(np.sum(a1),np.sum(a2))
print(np.mean(img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]]),
      np.mean(img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[1,4]:border[0,5]]))
cv2.imshow('a1',a1)
cv2.imshow('a2',a2)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imshow('a1',img1[:,:,50])
cv2.imshow('a2',img2[:,:,50])
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [[  0 512 461 512   0 126]
#  [  0 512   0  51   0 126]]
# 256186 170251
# 9.895661606656551 6.695875094829598

# %%
def increase_contrast(img1,img2,border):
    img1,img2=img1.astype('float64'),img2.astype('float64')
    ovl1=img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]]
    ovl2=img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[0,4]:border[0,5]]
    img1,img2=np.clip(20/np.mean(ovl1)*img1,0,255),np.clip(20/np.mean(ovl2)*img2,0,255)
    img1,img2=img1.astype('uint8'),img2.astype('uint8')
    return img1,img2

def adjust_contrast(img1,img2,border):
    img1,img2=img1.astype('float64'),img2.astype('float64')
    ovl1=img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]]
    ovl2=img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[0,4]:border[0,5]]
    m1,m2=np.mean(ovl1),np.mean(ovl2)
    if m1<m2:
        img1=np.clip(m2/m1*img1,0,255)
    else:
        img2=np.clip(m1/m2*img2,0,255)
    img1,img2=img1.astype('uint8'),img2.astype('uint8')
    return img1,img2

# %%
i,j=836,865
img1=import_img(img_path,i,dim_elem_num)
img2=import_img(img_path,j,dim_elem_num)
print(np.mean(img1))
border=get_2img_border(dim_elem_num,dim_len,voxel_len,np.vstack((tile_pos[i,:],tile_pos[j,:])))
cv2.imshow('a1',img1[:,:,100])
cv2.imshow('a2',img2[:,:,100])
cv2.waitKey()
cv2.destroyAllWindows()
img1,img2=adjust_contrast(img1,img2,border)
cv2.imshow('a1',img1[:,:,100])
cv2.imshow('a2',img2[:,:,100])
cv2.waitKey()
cv2.destroyAllWindows()
img_path=r'D:\Albert\Data\ZhaoLab\Imaging\20220219_Thy1_EGFP_M_high_resolution_40X_10overlap_50G'
print(border)
s=time.time()
xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,border,[30,30,30],3)
e=time.time()
print('totally %f'%(e-s))
# Out:
# 3.0740777575780474
# [[  0 512 461 512   0 126]
#  [  0 512   0  51   0 126]]
# -30 -30 -30
# (81, 482, 96) 0.6117493230137461
# -30 -30 -27
# (81, 482, 99) 0.6133289608496479
# -30 -30 -24
# (81, 482, 102) 0.6157358790603812
# -30 -30 -21
# (81, 482, 105) 0.6203794826762055
# -30 -30 -18
# (81, 482, 108) 0.622061066273123
# -30 -30 -15
# (81, 482, 111) 0.6244370532331368
# -30 -30 -12
# (81, 482, 114) 0.6276254020425116
# -30 -30 -9
# (81, 482, 117) 0.627724688340272
# -30 -30 -6
# (81, 482, 120) 0.6294206180763555
# -30 -30 -3
# (81, 482, 123) 0.6298229803817716
# -30 -30 0
# (81, 482, 126) 0.6285336297328689
# -30 -30 3
# (81, 482, 123) 0.6311184312697458
# -30 -30 6
# (81, 482, 120) 0.6367288103220707
# -30 -30 9
# (81, 482, 117) 0.6426141829958593
# -30 -30 12
# (81, 482, 114) 0.6502073647606041
# -30 -30 15
# (81, 482, 111) 0.6600408248113747
# -30 -30 18
# (81, 482, 108) 0.6662104640822161
# -30 -30 21
# (81, 482, 105) 0.6726518564084701
# -30 -30 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [48], in <cell line: 18>()
#      16 print(border)
#      17 s=time.time()
# ---> 18 xyz_shift=calculate_img_xyz_shift(img1,img2,dim_elem_num,border,[30,30,30],3)
#      19 e=time.time()
#      20 print('totally %f'%(e-s))
#
# Input In [3], in calculate_img_xyz_shift(img1, img2, dim_elem_num, voxel_border, voxel_range, step)
#     122 border=get_2img_border_after_shift(dim_elem_num,voxel_border,[x,y,z])
#     123 print(x,y,z)
# --> 124 this_loss=loss_fun(img1[border[0,2]:border[0,3],border[0,0]:border[0,1],border[0,4]:border[0,5]],
#     125                    img2[border[1,2]:border[1,3],border[1,0]:border[1,1],border[1,4]:border[1,5]],[x,y,z],alpha)
#     126 if this_loss<loss_min:
#     127     loss_min=this_loss
#
# Input In [3], in loss_fun(ovl1, ovl2, xyz_shift, alpha)
#      66     print('no overlapping area')
#      67     return np.inf
# ---> 68 ovl1,ovl2=ovl1.astype('int64'),ovl2.astype('int64')
#      69 a=np.float64(np.sum((ovl1-ovl2)**2))/(np.sqrt(np.float64(np.sum(ovl1**2)))*np.sqrt(np.float64(np.sum(ovl1**2))))+alpha*np.sum(np.array(xyz_shift,dtype='float64')**2)
#      70 print(ovl1.shape,a)
#
# KeyboardInterrupt:
