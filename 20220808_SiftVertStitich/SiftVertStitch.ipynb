# %%
from lxml import etree
import numpy as np
import time
import cv2
import random
import sys

def get_img_xml_info(xml_path):
    '''
    Read xml file and extract the information of dimensions and each tile
    return - (1)dim_elem_num - linspace(uint), the quantity of voxels for each dimension,
    (2)dim_len - linspace(float), the length for one 3D image,
    (3)voxel_len - lingspace(float), the length for a voxel,
    (4)tile_num - int, the quantity of tiles,
    (5)tile_field - array(uint), the identifier of each file
    (6)tile_pos - array(float), the XYZ position information of each tile
    '''
    parser=etree.XMLParser()
    my_et=etree.parse(xml_path,parser=parser)
    dim_attrib=my_et.xpath('//Dimensions/DimensionDescription')
    dim_elem_num=np.zeros(3,dtype='uint')
    dim_len=np.zeros(3)
    for i in range(3):
        dim_elem_num[i],dim_len[i]=dim_attrib[i].attrib['NumberOfElements'],dim_attrib[i].attrib['Length']
    voxel_len=dim_len/dim_elem_num
    return dim_elem_num,dim_len,voxel_len

def import_2D_img(img_path,img_name,z_th):
    one_img_name=r'%s\%s_z%.2d_RAW_ch00.tif'%(img_path,img_name,z_th)
    return cv2.imread(one_img_name,cv2.IMREAD_GRAYSCALE)

def pyr_down_img(img,times=1):
    img_down=cv2.pyrDown(img)
    for i in range(times-1):
        img_down=cv2.pyrDown(img_down)
    return img_down

def loss_fun(ovl1,ovl2):
    ovl1,ovl2=ovl1.astype('float32'),ovl2.astype('float32')
    loss=np.sum((ovl1-ovl2)**2)/np.sqrt(np.sum(ovl1**2)*np.sum(ovl2**2))
    return loss

def calculate_xy_shift_by_RANSAC(img1,img2,pts1,pts2,loss_threshold=1,sample_time=1000):
    count=0
    matches_num=pts1.shape[0]
    RANSAC_num=np.int32(np.min((2,matches_num*0.1)))
    loss_threshold=0.05
    loss_min=np.inf
    xy_shift_min=np.zeros(2)
    while(loss_min>loss_threshold and count<sample_time):
        count+=1
        index_list=random.sample(range(matches_num),RANSAC_num)
        xy_shift_all=pts2[index_list,:]-pts1[index_list,:]
        max_shift,min_shift=np.max(xy_shift_all,axis=0),np.min(xy_shift_all,axis=0)
        if any((max_shift-min_shift)>50):
            continue
        xy_shift=np.int32(np.round(np.mean(xy_shift_all,axis=0)))#XY
        if all(xy_shift==xy_shift_min):
            continue
        ovl1,ovl2=img1[np.max((0,-xy_shift[1])):,np.max((0,-xy_shift[0])):],img2[np.max((0,xy_shift[1])):,np.max((0,xy_shift[0])):]
        x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1])),np.min((ovl1.shape[0],ovl2.shape[0]))
        ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
        this_loss=loss_fun(ovl1,ovl2)
        #print(xy_shift,this_loss)
        if this_loss<loss_min:
            loss_min=this_loss
            xy_shift_min=xy_shift
    #print(xy_shift_min,loss_min)
    return xy_shift_min,loss_min

def calculate_xy_shift_by_BF(img1_down,img2_down,img1,img2,xy_shift):
    ################################################################
    xy_shift_min=np.zeros(0)
    loss_min=np.inf
    for x in range(-5,6):
        for y in range(-5,6):
            this_xy_shift=xy_shift+np.array([x,y],dtype='int32')
            ovl1=img1_down[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2_down[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1])),np.min((ovl1.shape[0],ovl2.shape[0]))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
            #print(this_xy_shift,this_loss)
    #print('first ',xy_shift_min,loss_min)
    ################################################################
    xy_shift_whole=xy_shift_min*4
    xy_shift_min=np.zeros(0)
    loss_min=np.inf
    for x in range(-18,19,3):
        for y in range(-18,19,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
#             if x==0 and y==0:
#                 cv2.imshow('1',ovl1)
#                 cv2.imshow('2',ovl2)
#                 cv2.waitKey()
#                 cv2.destroyAllWindows()
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    #print(xy_shift_min)
    xy_shift_whole=xy_shift_min
    for x in range(-2,3):
        for y in range(-2,3):
            this_xy_shift=xy_shift_whole+np.array([x,y],dtype='int32')
            ovl1=img1[np.max((0,-this_xy_shift[1])):,np.max((0,-this_xy_shift[0])):]
            ovl2=img2[np.max((0,this_xy_shift[1])):,np.max((0,this_xy_shift[0])):]
            x_range,y_range=np.min((ovl1.shape[1],ovl2.shape[1],2000)),np.min((ovl1.shape[0],ovl2.shape[0],2000))
            ovl1,ovl2=ovl1[0:y_range,0:x_range],ovl2[0:y_range,0:x_range]
            this_loss=loss_fun(ovl1,ovl2)
            if this_loss<loss_min:
                loss_min=this_loss
                xy_shift_min=this_xy_shift
    #print('second ',xy_shift_min,loss_min)
    return xy_shift_min,loss_min

def update_lower_layer_info(xy_shift,axis_range1,axis_range2,voxel_len):
    axis_range2[0,0]=-axis_range2[0,0]+axis_range1[0,0]-xy_shift[0]*voxel_len[0]
    axis_range2[0,1]=-axis_range2[0,0]+axis_range1[0,0]-xy_shift[0]*voxel_len[0]
    axis_range2[1,0]=-axis_range2[1,0]+axis_range1[1,0]-xy_shift[1]*voxel_len[1]
    axis_range2[1,1]=-axis_range2[1,0]+axis_range1[1,0]-xy_shift[1]*voxel_len[1]
    return axis_range2

def adjust_contrast(img1,img2):
    img1,img2=img1.astype('float32'),img2.astype('float32')
    m1,m2=np.mean(img1),np.mean(img2)
    m=np.max((m1,m2))
    img1=np.uint8(np.clip(m/m1*img1,0,255))
    img2=np.uint8(np.clip(m/m2*img2,0,255))
    return img1,img2

def find_roi_region(img,thredshold=5):
    roi_range=np.zeros((2,2),dtype='uint32')
    lr_roi_index=[i for [i] in np.argwhere(np.mean(img,axis=0)>thredshold)]
    ud_roi_index=[i for [i] in np.argwhere(np.mean(img,axis=1)>thredshold)]
    roi_range[0,0],roi_range[0,1]=min(lr_roi_index),max(lr_roi_index)
    roi_range[1,0],roi_range[1,1]=min(ud_roi_index),max(ud_roi_index)
    return img[roi_range[1,0]:roi_range[1,1],roi_range[0,0]:roi_range[0,1]],roi_range

def start_vertical_stitch(i,img_path,save_path,file_name,img_name):
    sift=cv2.xfeatures2d.SIFT_create()
    bf=cv2.BFMatcher()
    img_path1,img_path2=img_path+'\\'+file_name%(i),img_path+'\\'+file_name%(i+1)
    xml_path1,xml_path2=img_path+'\\'+file_name%(i)+r'\MetaData'+'\\'+img_name+'.xml',img_path+'\\'+file_name%(i+1)+r'\MetaData'+'\\'+img_name+'.xml'
    dim_elem_num1,dim_len1,voxel_len=get_img_xml_info(xml_path1)
    dim_elem_num2,dim_len2,_=get_img_xml_info(xml_path2)
    axis_range1,axis_range2=np.load(save_path+r'\axis_range_%d.npy'%(i)),np.load(save_path+r'\axis_range_%d.npy'%(i+1))
    img2=import_2D_img(img_path2,img_name,0)
    img2,roi_range2=find_roi_region(img2)
    img2_down=pyr_down_img(img2,2)
    
    
    step=1
    loss_min=np.inf
    index_min=-1
    xy_shift_min=np.zeros(2)
    for j in range(dim_elem_num1[2]-10,np.uint32(np.round(dim_elem_num1[2]*0.3)),-step):
        img1=import_2D_img(img_path1,img_name,j)
        img1,roi_range1=find_roi_region(img1)
        img1_down=pyr_down_img(img1,2)
        img2_down=pyr_down_img(img2,2)
        img1_down,img2_down=adjust_contrast(img1_down,img2_down)
        kpts1,des1=sift.detectAndCompute(img1_down,None)
        kpts2,des2=sift.detectAndCompute(img2_down,None)
        kp1,kp2=np.float32([kp.pt for kp in kpts1]),np.float32([kp.pt for kp in kpts2])
        matches=bf.knnMatch(des1,des2,k=2)
        good_matches=[]
        good=[]
        for m in matches:
            if len(m)==2 and m[0].distance<0.75*m[1].distance:
                good_matches.append((m[0].queryIdx,m[0].trainIdx))
                good.append(m[0])
        img3=cv2.drawMatches(img1_down,kpts1,img2_down,kpts2,good,None,flags=2)
        cv2.imshow('3',img3)
        cv2.waitKey(3000)
        cv2.destroyAllWindows()
        pts1,pts2=np.float32([kp1[i,:] for (i,_) in good_matches]),np.float32([kp2[j,:] for (_,j) in good_matches])
        xy_shift,this_loss=calculate_xy_shift_by_RANSAC(img1_down,img2_down,pts1,pts2)
        print('%d.th layer for pyrDown image, xy_shift is %s, loss is %.8f'%(j,str(xy_shift),this_loss))
        xy_shift,this_loss=calculate_xy_shift_by_BF(img1_down,img2_down,img1,img2,xy_shift)
        print('%d.th layer for whole image, xy_shift is %s, loss is %.8f'%(j,str(xy_shift),this_loss))
        if this_loss<loss_min:
            loss_min=this_loss
            xy_shift_min[0],xy_shift_min[1]=xy_shift[0]+roi_range2[0,0]-roi_range1[0,0],xy_shift[0]+roi_range2[1,0]-roi_range1[1,0]
            index_min=j
    print('################################################################################')
    print('Finally the matched one is %d.th layer, xy_shift is %s, loss is %.8f'%(index_min,str(xy_shift_min),loss_min))
    print('################################################################################')
    
    print('start saving data')
    axis_range2=update_lower_layer_info(xy_shift_min,axis_range1,axis_range2,voxel_len)
    np.save(save_path+r'\first_index_%d.npy'%(i+1),np.array([dim_elem_num[2]-index_min],dtype='uint32'))
    np.save(save_path+r'\axis_range_stitch_%d.npy'%(i+1),axis_range2)
    print('end saving data')

# %%
img_path=r'C:\Users\dingj\ZhaoLab'
file_name=r'Project%d'
img_name=r'Region 1_Merged'
save_path=r'C:\Users\dingj\ZhaoLab\20220808_SiftVertStitich_MSR'
layer_num=3
for i in range(1,layer_num+1):
    xml_path=img_path+'\\'+file_name%(i)+r'\MetaData'+'\\'+img_name+'.xml'
    dim_elem_num,dim_len,voxel_len=get_img_xml_info(xml_path)
    axis_range=np.zeros((2,2))
    axis_range[0,1],axis_range[1,1]=dim_len[0],dim_len[1]
    #np.save('first_last_index_%d.npy'%(i),np.array([0,dim_elem_num[2]-1]))
    np.save(save_path+r'\axis_range_%d.npy'%(i),axis_range)
    if i==1:
        np.save(save_path+r'\axis_range_stitch_%d.npy'%(i),axis_range)

for i in range(1,layer_num):
    start_vertical_stitch(i,img_path,save_path,file_name,img_name)
# Out:
# 73.th layer for pyrDown image, xy_shift is [ 80 -73], loss is 0.87126195
# 73.th layer for whole image, xy_shift is [ 298 -257], loss is 0.93835229
# 72.th layer for pyrDown image, xy_shift is [-256 -147], loss is 0.93997133
# 72.th layer for whole image, xy_shift is [-984 -614], loss is 0.97304702
# 71.th layer for pyrDown image, xy_shift is [-264  126], loss is 1.04500329
# 71.th layer for whole image, xy_shift is [-1016   532], loss is 1.00901592
# 70.th layer for pyrDown image, xy_shift is [-197 -208], loss is 0.90158623
# 70.th layer for whole image, xy_shift is [-748 -840], loss is 0.94850528
# 69.th layer for pyrDown image, xy_shift is [-27 -22], loss is 0.74769270
# 69.th layer for whole image, xy_shift is [-107  -85], loss is 0.79024857
# 68.th layer for pyrDown image, xy_shift is [-205 -165], loss is 0.88729662
# 68.th layer for whole image, xy_shift is [-848 -700], loss is 0.93854380
# 67.th layer for pyrDown image, xy_shift is [-216 -287], loss is 0.93783927
# 67.th layer for whole image, xy_shift is [ -890 -1164], loss is 1.04734576
# 66.th layer for pyrDown image, xy_shift is [-236  116], loss is 0.98905414
# 66.th layer for whole image, xy_shift is [-952  424], loss is 0.98904520
# 65.th layer for pyrDown image, xy_shift is [-202 -255], loss is 0.96581298
# 65.th layer for whole image, xy_shift is [-829 -980], loss is 1.03612649
# 64.th layer for pyrDown image, xy_shift is [-19 -13], loss is 0.63912791
# 64.th layer for whole image, xy_shift is [-78 -47], loss is 0.67418510
# 63.th layer for pyrDown image, xy_shift is [-17 -11], loss is 0.61895031
# 63.th layer for whole image, xy_shift is [-73 -41], loss is 0.65141720
# 62.th layer for pyrDown image, xy_shift is [-14  -7], loss is 0.61136121
# 62.th layer for whole image, xy_shift is [-67 -34], loss is 0.62638402
# 61.th layer for pyrDown image, xy_shift is [-15  -7], loss is 0.55843395
# 61.th layer for whole image, xy_shift is [-60 -28], loss is 0.59806752
# 60.th layer for pyrDown image, xy_shift is [-14  -6], loss is 0.53429413
# 60.th layer for whole image, xy_shift is [-54 -22], loss is 0.57387882
# 59.th layer for pyrDown image, xy_shift is [-12  -4], loss is 0.50915956
# 59.th layer for whole image, xy_shift is [-48 -17], loss is 0.54948658
# 58.th layer for pyrDown image, xy_shift is [-11  -2], loss is 0.48439389
# 58.th layer for whole image, xy_shift is [-42  -9], loss is 0.52442282
# 57.th layer for pyrDown image, xy_shift is [-9 -1], loss is 0.46396786
# 57.th layer for whole image, xy_shift is [-37  -4], loss is 0.50279844
# 56.th layer for pyrDown image, xy_shift is [-8  1], loss is 0.44441086
# 56.th layer for whole image, xy_shift is [-33   3], loss is 0.48372388
# 55.th layer for pyrDown image, xy_shift is [-7  2], loss is 0.42721757
# 55.th layer for whole image, xy_shift is [-26   9], loss is 0.46603027
# 54.th layer for pyrDown image, xy_shift is [-5  4], loss is 0.41520086
# 54.th layer for whole image, xy_shift is [-21  14], loss is 0.45176613
# 53.th layer for pyrDown image, xy_shift is [-4  5], loss is 0.40392685
# 53.th layer for whole image, xy_shift is [-14  22], loss is 0.44001609
# 52.th layer for pyrDown image, xy_shift is [-2  7], loss is 0.39505643
# 52.th layer for whole image, xy_shift is [-9 30], loss is 0.43013501
# 51.th layer for pyrDown image, xy_shift is [-1  9], loss is 0.38653347
# 51.th layer for whole image, xy_shift is [-2 37], loss is 0.42111340
# 50.th layer for pyrDown image, xy_shift is [ 1 11], loss is 0.37936059
# 50.th layer for whole image, xy_shift is [ 5 45], loss is 0.41385403
# 49.th layer for pyrDown image, xy_shift is [ 3 13], loss is 0.37475815
# 49.th layer for whole image, xy_shift is [11 53], loss is 0.40666056
# 48.th layer for pyrDown image, xy_shift is [ 5 15], loss is 0.37054896
# 48.th layer for whole image, xy_shift is [19 61], loss is 0.40163222
# 47.th layer for pyrDown image, xy_shift is [ 7 17], loss is 0.36858681
# 47.th layer for whole image, xy_shift is [28 69], loss is 0.39917022
# 46.th layer for pyrDown image, xy_shift is [ 8 19], loss is 0.36850739
# 46.th layer for whole image, xy_shift is [32 77], loss is 0.39950266
# 45.th layer for pyrDown image, xy_shift is [ 9 22], loss is 0.37270683
# 45.th layer for whole image, xy_shift is [36 87], loss is 0.40341869
# 44.th layer for pyrDown image, xy_shift is [10 24], loss is 0.37979010
# 44.th layer for whole image, xy_shift is [40 96], loss is 0.41014761
# 43.th layer for pyrDown image, xy_shift is [11 26], loss is 0.38974193
# 43.th layer for whole image, xy_shift is [ 44 104], loss is 0.42110446
# 42.th layer for pyrDown image, xy_shift is [12 29], loss is 0.40108359
# 42.th layer for whole image, xy_shift is [ 48 115], loss is 0.43575588
# 41.th layer for pyrDown image, xy_shift is [13 32], loss is 0.41148823
# 41.th layer for whole image, xy_shift is [ 53 126], loss is 0.44904727
# 40.th layer for pyrDown image, xy_shift is [15 34], loss is 0.42053258
# 40.th layer for whole image, xy_shift is [ 59 135], loss is 0.46097985
# 39.th layer for pyrDown image, xy_shift is [17 36], loss is 0.43010208
# 39.th layer for whole image, xy_shift is [ 67 143], loss is 0.47426739
# 38.th layer for pyrDown image, xy_shift is [18 38], loss is 0.43806583
# 38.th layer for whole image, xy_shift is [ 71 151], loss is 0.48408872
# 37.th layer for pyrDown image, xy_shift is [19 40], loss is 0.44680718
# 37.th layer for whole image, xy_shift is [ 75 160], loss is 0.49517426
# 36.th layer for pyrDown image, xy_shift is [20 43], loss is 0.45542881
# 36.th layer for whole image, xy_shift is [ 81 171], loss is 0.50659472
# 35.th layer for pyrDown image, xy_shift is [23 45], loss is 0.46323812
# 35.th layer for whole image, xy_shift is [ 90 181], loss is 0.51333797
# 34.th layer for pyrDown image, xy_shift is [25 47], loss is 0.47134656
# 34.th layer for whole image, xy_shift is [102 189], loss is 0.52272111
# 33.th layer for pyrDown image, xy_shift is [29 50], loss is 0.48161566
# 33.th layer for whole image, xy_shift is [116 198], loss is 0.53558940
# 32.th layer for pyrDown image, xy_shift is [32 53], loss is 0.49290705
# 32.th layer for whole image, xy_shift is [128 210], loss is 0.54764289
# 31.th layer for pyrDown image, xy_shift is [37 55], loss is 0.50378704
# 31.th layer for whole image, xy_shift is [148 221], loss is 0.56042743
# 30.th layer for pyrDown image, xy_shift is [39 58], loss is 0.51967108
# 30.th layer for whole image, xy_shift is [156 231], loss is 0.57885706
# 29.th layer for pyrDown image, xy_shift is [40 59], loss is 0.53945392
# 29.th layer for whole image, xy_shift is [161 240], loss is 0.59743315
# 28.th layer for pyrDown image, xy_shift is [42 63], loss is 0.55305189
# 28.th layer for whole image, xy_shift is [168 251], loss is 0.61530596
# 27.th layer for pyrDown image, xy_shift is [44 67], loss is 0.57199264
# 27.th layer for whole image, xy_shift is [175 264], loss is 0.63421929
# 26.th layer for pyrDown image, xy_shift is [46 71], loss is 0.59616989
# 26.th layer for whole image, xy_shift is [181 275], loss is 0.65307128
# ################################################################################
# Finally the matched one is 47.th layer, xy_shift is [-75. 366.], loss is 0.39917022
# ################################################################################
# start saving data
# end saving data
# 64.th layer for pyrDown image, xy_shift is [-448 -434], loss is 0.92765611
# 64.th layer for whole image, xy_shift is [-1792 -1696], loss is 1.39889967
# 63.th layer for pyrDown image, xy_shift is [-276 -322], loss is 0.84146500
# 63.th layer for whole image, xy_shift is [-1135 -1248], loss is 1.90233850
# 62.th layer for pyrDown image, xy_shift is [-210 -349], loss is 0.89428586
# 62.th layer for whole image, xy_shift is [ -864 -1436], loss is 1.86908007
# 61.th layer for pyrDown image, xy_shift is [-202 -320], loss is 0.91562945
# 61.th layer for whole image, xy_shift is [ -848 -1296], loss is 1.90791917
# 60.th layer for pyrDown image, xy_shift is [-240 -172], loss is 0.92155743
# 60.th layer for whole image, xy_shift is [-996 -728], loss is 2.13152480
# 59.th layer for pyrDown image, xy_shift is [-449 -405], loss is 0.80998528
# 59.th layer for whole image, xy_shift is [-1785 -1617], loss is 1.26939774
# 58.th layer for pyrDown image, xy_shift is [-425 -265], loss is 0.81027848
# 58.th layer for whole image, xy_shift is [-1740 -1020], loss is 1.49091816
# 57.th layer for pyrDown image, xy_shift is [-236 -212], loss is 0.91749573
# 57.th layer for whole image, xy_shift is [-984 -888], loss is 1.89005864
# 56.th layer for pyrDown image, xy_shift is [-280 -291], loss is 0.79047513
# 56.th layer for whole image, xy_shift is [-1131 -1156], loss is 1.73104811
# 55.th layer for pyrDown image, xy_shift is [-294 -176], loss is 0.91408288
# 55.th layer for whole image, xy_shift is [-1204  -692], loss is 1.90730476
# 54.th layer for pyrDown image, xy_shift is [-225 -210], loss is 0.90652496
# 54.th layer for whole image, xy_shift is [-900 -880], loss is 1.86235249
# 53.th layer for pyrDown image, xy_shift is [-448 -296], loss is 0.78025776
# 53.th layer for whole image, xy_shift is [-1792 -1184], loss is 1.34500527
# 52.th layer for pyrDown image, xy_shift is [-205 -122], loss is 0.98433840
# 52.th layer for whole image, xy_shift is [-820 -528], loss is 2.10103798
# 51.th layer for pyrDown image, xy_shift is [-450 -272], loss is 0.78959310
# 51.th layer for whole image, xy_shift is [-1804 -1128], loss is 1.31975436
# 50.th layer for pyrDown image, xy_shift is [-202 -176], loss is 0.91121280
# 50.th layer for whole image, xy_shift is [-768 -671], loss is 1.90248740
# 49.th layer for pyrDown image, xy_shift is [-238 -221], loss is 0.81873906
# 49.th layer for whole image, xy_shift is [-939 -898], loss is 1.69019508
# 48.th layer for pyrDown image, xy_shift is [-430 -287], loss is 0.77206993
# 48.th layer for whole image, xy_shift is [-1720 -1160], loss is 1.33015752
# 47.th layer for pyrDown image, xy_shift is [-404 -387], loss is 0.84736872
# 47.th layer for whole image, xy_shift is [-1576 -1537], loss is 1.20511746
# 46.th layer for pyrDown image, xy_shift is [-17 -12], loss is 0.77579015
# 46.th layer for whole image, xy_shift is [-54 -32], loss is 1.87828767
# 45.th layer for pyrDown image, xy_shift is [-16  -9], loss is 0.75017589
# 45.th layer for whole image, xy_shift is [-48 -27], loss is 1.80599356
# 44.th layer for pyrDown image, xy_shift is [-11  -6], loss is 0.70068246
# 44.th layer for whole image, xy_shift is [-46 -22], loss is 1.74357498
# 43.th layer for pyrDown image, xy_shift is [-9 -5], loss is 0.67975253
# 43.th layer for whole image, xy_shift is [-40 -18], loss is 1.68073726
# 42.th layer for pyrDown image, xy_shift is [-10  -4], loss is 0.65117943
# 42.th layer for whole image, xy_shift is [-38 -12], loss is 1.61568129
# 41.th layer for pyrDown image, xy_shift is [-5 -2], loss is 0.63300240
# 41.th layer for whole image, xy_shift is [-18  -8], loss is 1.56144762
# 40.th layer for pyrDown image, xy_shift is [-5 -1], loss is 0.61121374
# 40.th layer for whole image, xy_shift is [-17  -2], loss is 1.50649333
# 39.th layer for pyrDown image, xy_shift is [-2  0], loss is 0.58697897
# 39.th layer for whole image, xy_shift is [-8  3], loss is 1.44742310
# 38.th layer for pyrDown image, xy_shift is [-2  1], loss is 0.56633174
# 38.th layer for whole image, xy_shift is [-7  7], loss is 1.39854681
# 37.th layer for pyrDown image, xy_shift is [-1  3], loss is 0.54691797
# 37.th layer for whole image, xy_shift is [-5 13], loss is 1.34958947
# 36.th layer for pyrDown image, xy_shift is [-1  4], loss is 0.52627856
# 36.th layer for whole image, xy_shift is [-4 18], loss is 1.29873586
# 35.th layer for pyrDown image, xy_shift is [0 5], loss is 0.51185417
# 35.th layer for whole image, xy_shift is [ 1 22], loss is 1.25673425
# 34.th layer for pyrDown image, xy_shift is [0 7], loss is 0.50037277
# 34.th layer for whole image, xy_shift is [ 2 27], loss is 1.21561551
# 33.th layer for pyrDown image, xy_shift is [1 8], loss is 0.48948327
# 33.th layer for whole image, xy_shift is [ 4 34], loss is 1.17786980
# 32.th layer for pyrDown image, xy_shift is [2 9], loss is 0.48573962
# 32.th layer for whole image, xy_shift is [ 8 38], loss is 1.14901686
# 31.th layer for pyrDown image, xy_shift is [ 3 11], loss is 0.48590553
# 31.th layer for whole image, xy_shift is [12 44], loss is 1.12322593
# 30.th layer for pyrDown image, xy_shift is [ 5 12], loss is 0.49030992
# 30.th layer for whole image, xy_shift is [19 49], loss is 1.10055804
# 29.th layer for pyrDown image, xy_shift is [ 6 14], loss is 0.49666733
# 29.th layer for whole image, xy_shift is [24 55], loss is 1.08363891
# 28.th layer for pyrDown image, xy_shift is [ 7 15], loss is 0.50513685
# 28.th layer for whole image, xy_shift is [28 62], loss is 1.06889975
# 27.th layer for pyrDown image, xy_shift is [ 9 17], loss is 0.51672804
# 27.th layer for whole image, xy_shift is [35 68], loss is 1.05573976
# 26.th layer for pyrDown image, xy_shift is [11 18], loss is 0.52911615
# 26.th layer for whole image, xy_shift is [42 74], loss is 1.04663849
# 25.th layer for pyrDown image, xy_shift is [12 20], loss is 0.54078245
# 25.th layer for whole image, xy_shift is [47 80], loss is 1.03960299
# 24.th layer for pyrDown image, xy_shift is [14 21], loss is 0.55280912
# 24.th layer for whole image, xy_shift is [57 86], loss is 1.03413260
# 23.th layer for pyrDown image, xy_shift is [16 23], loss is 0.56615871
# 23.th layer for whole image, xy_shift is [64 91], loss is 1.03014576
# ################################################################################
# Finally the matched one is 23.th layer, xy_shift is [-25.  38.], loss is 1.03014576
# ################################################################################
# start saving data
# end saving data

# %%
from lxml import etree
import numpy as np
import time
import cv2
import random
import sys

a=np.array([[1,2,3],[2,3,4],[4,5,6],[6,7,8]])
[i for [i] in np.argwhere(np.mean(a,axis=0)>1)]
# Out:
# [0, 1, 2]
